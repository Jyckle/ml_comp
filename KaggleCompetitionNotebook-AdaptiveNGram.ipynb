# %% [markdown]
# # Kaggle Competition Notebook

# %% [markdown]
# ### Import necessary libraries

# %%
import math
import pandas as pd
import numpy as np
import re
import time
import unicodedata as ud

# %% [markdown]
# ### Prep data for N Gram Model

# %%
def prepare_data(filename, N):
    pre_string = "<s>"
    post_string = "</s>"
    train_dat = []
        
    with open(filename) as file:
        for line in file:
            line = re.sub(' +',' ',line)
            line = re.sub('[,\."“”]','',line)
            split_line = line.strip().split()
            for gram in range(1,N):
                split_line.insert(0,pre_string)
                split_line.append(post_string)
            train_dat.append(split_line)
    
    return train_dat

# %%
train_data = prepare_data('train.txt',3)

# %%
train_data[0:10]
# Out:
# [['<s>',
#   '<s>',
#   'Nuair',
#   'atá',
#   'cúiseanna',
#   'á',
#   'gcur',
#   'ar',
#   'an',
#   'taifead',
#   'poiblí',
#   'nó',
#   'le',
#   'linn',
#   'ráiteas',
#   'poiblí',
#   'a',
#   'dhéanamh',
#   'ní',
#   'mór',
#   'don',
#   'ionchúisitheoir',
#   'cúram',
#   'a',
#   'ghlacadh',
#   'gan',
#   'náire',
#   'a',
#   'chur',
#   'ar',
#   'an',
#   'gcúisí',
#   'ná',
#   'ar',
#   'fhinnéithe',
#   'trí',
#   'eolas',
#   'a',
#   'nochtadh',
#   'nach',
#   'gcuirfear',
#   'ar',
#   'fáil',
#   'go',
#   'poiblí',
#   'murach',
#   'sin',
#   '</s>',
#   '</s>'],
#  ['<s>',
#   '<s>',
#   'Tá',
#   'cinneadh',
#   'déanta',
#   'ag',
#   'Killoran',
#   'agus',
#   'ag',
#   'a',
#   'comhghleacaithe',
#   'an',
#   'bhéim',
#   'a',
#   'chur',
#   'ar',
#   'an',
#   'drámaíocht',
#   'agus',
#   'airgead',
#   'Chiste',
#   'Craoltóireachta',
#   'na',
#   'Gaeilge',
#   'á',
#   'dháileadh',
#   '</s>',
#   '</s>'],
#  ['<s>',
#   '<s>',
#   'Thug',
#   'Luiz',
#   'Henrique',
#   'Uaquim',
#   'uachtarán',
#   'chomharchumann',
#   'fheirmeoirí',
#   'an',
#   'réigiúin',
#   'bithiúnaigh',
#   'gléasta',
#   'suas',
#   'mar',
#   'Indiaigh',
#   'ar',
#   'na',
#   'Tupinambá-de-OlivenÁa',
#   'nuair',
#   'a',
#   'chas',
#   'mé',
#   'leis',
#   '</s>',
#   '</s>'],
#  ['<s>',
#   '<s>',
#   'Lena',
#   'cheart',
#   'a',
#   'thabhairt',
#   'dó',
#   'dhein',
#   'sé',
#   'a',
#   'chúram',
#   'go',
#   'slachtmhar',
#   '</s>',
#   '</s>'],
#  ['<s>',
#   '<s>',
#   'Tar',
#   'éis',
#   'scrúdaithe',
#   'fadálach',
#   'dheimhnigh',
#   'na',
#   'Coimisinéirí',
#   'Ioncaim',
#   'i',
#   'Meitheamh',
#   '2007',
#   'gur',
#   'bhain',
#   'siad',
#   'amach',
#   'go',
#   'ndearna',
#   'duine',
#   'dá',
#   'gcuid',
#   'oifigeach',
#   'rochtain',
#   'ar',
#   'thaifid',
#   'sonraí',
#   'an',
#   'damhna',
#   'sonraí',
#   'agus',
#   'a',
#   'muintire',
#   'sa',
#   'tréimhse',
#   'Samhain',
#   '2006',
#   'go',
#   'Feabhra',
#   '2007',
#   'nach',
#   'raibh',
#   'an',
#   'rochtain',
#   '</s>',
#   '</s>'],
#  ['<s>',
#   '<s>',
#   '(7)',
#   'Aon',
#   'rialacháin',
#   'faoi',
#   'alt',
#   '32',
#   'den',
#   'Acht',
#   'um',
#   'Iompras',
#   'Bhaile',
#   'Átha',
#   'Cliath',
#   '1986',
#   'a',
#   'bheidh',
#   'i',
#   'bhfeidhm',
#   'díreach',
#   'roimh',
#   'thosach',
#   'feidhme',
#   'an',
#   'Achta',
#   'um',
#   'Iompras',
#   'Bhaile',
#   'Átha',
#   'Cliath',
#   '(Díscaoileadh)',
#   '1987',
#   'leanfaidh',
#   'siad',
#   'de',
#   'bheith',
#   'i',
#   'bhfeidhm',
#   'tar',
#   'éis',
#   'an',
#   'tosach',
#   'feidhme',
#   'sin',
#   'agus',
#   'féadfar',
#   'iad',
#   'a',
#   'leasú',
#   'nó',
#   'a',
#   'chúlghairm',
#   'amhail',
#   'is',
#   'dá',
#   'mba',
#   'faoin',
#   'alt',
#   'seo',
#   'a',
#   'rinneadh',
#   'iad',
#   '</s>',
#   '</s>'],
#  ['<s>',
#   '<s>',
#   'Bhíothas',
#   'ag',
#   'cur',
#   'ar',
#   'Nuala',
#   'Bhilí',
#   "'Ic",
#   'Niallais',
#   'nuair',
#   'a',
#   'chuala',
#   'sí',
#   'gur',
#   'imeacht',
#   'a',
#   'rinne',
#   'sé',
#   'gur',
#   'dhúirt',
#   'sí',
#   'go',
#   "mb'fhearr",
#   'léi',
#   'fear',
#   'dá',
#   'raibh',
#   'amuigh',
#   'sa',
#   'bhád',
#   'a',
#   'chluinstin',
#   'ag',
#   'scairtigh',
#   'leis',
#   'an',
#   'mhuintir',
#   'a',
#   'bhí',
#   'ar',
#   'an',
#   'chladach',
#   'go',
#   'raibh',
#   'sé',
#   'anseo',
#   'ina',
#   'luí',
#   'báite',
#   'ar',
#   'thóin',
#   'na',
#   'farraige',
#   '</s>',
#   '</s>'],
#  ['<s>',
#   '<s>',
#   'Léamhthuiscint',
#   '02',
#   '–',
#   'Ar',
#   'cheart',
#   'bainisteoirí',
#   'CLG',
#   'a',
#   'íoc?',
#   '</s>',
#   '</s>'],
#  ['<s>',
#   '<s>',
#   '@psychusup',
#   'Sin',
#   'ceann',
#   'de',
#   'na',
#   'rudaí',
#   'is',
#   'tábhachtaí',
#   'a',
#   'chaithfimid',
#   'a',
#   'athrú',
#   'Gaeilge',
#   'líofa',
#   'riachtanach',
#   "d'éinne",
#   'ag',
#   'obair',
#   'sa',
#   'rialtas',
#   'Gaeilge',
#   '#1',
#   'acu',
#   '</s>',
#   '</s>'],
#  ['<s>',
#   '<s>',
#   'Cé',
#   'hé',
#   'inis',
#   'dom',
#   'cé',
#   'hé',
#   'an',
#   'fear',
#   'seo',
#   'nach',
#   'dtuigeann',
#   'tú',
#   'go',
#   'gcaithfidh',
#   'sé',
#   'tú',
#   'a',
#   'phósadh',
#   'mura',
#   'bpósann',
#   'sé',
#   'tu',
#   'beidhmid',
#   'náirithe',
#   'ós',
#   'comhair',
#   'an',
#   'pharóiste!',
#   '</s>',
#   '</s>']]

# %%
def train_model(train_data, N):
    model = {}
    for line in train_data:
        for each_N in range(1,N+1):
            #for each line, generate all ngrams
            for index in range(0,len(line)-each_N):
                ngram = line[index]
                for n_forward in range(1,each_N):
                    ngram += ' ' + line[index+n_forward]
                if ngram in model:
                    model[ngram] += 1
                else:
                    model[ngram] = 1
    return model

# %%
model = train_model(train_data,3)

# %% [markdown]
# ### Import Training data and examine

# %%
def prepare_test_data(filename, N):
    choices=[]
    reg_exp_str = '\{(.*)\|(.*)\}'
    pre_string = ''
    post_string = ''
    for gram in range(1,N):
        pre_string += '<s> '
        post_string += ' </s>'
        if gram % 2 == 0:
            reg_exp_str = reg_exp_str + ' ([^ ]*)'
        else:
            reg_exp_str = '([^ ]*) ' + reg_exp_str
    reg_exp = re.compile(reg_exp_str)
    with open(filename) as file:
        for row in file:
            row = re.sub(' +',' ',row)
            row = re.sub('[,\."“”]','',row)
            row = pre_string + row + post_string
            #extract options
            match = reg_exp.search(row)
            if match:
            #THIS NEEDS TO BE FIXED
                midpoint = math.ceil(N/2)
                choice_1 = match.group(midpoint)
                choice_2 = match.group(midpoint+1)
                for match_group in range(1,N+2):
                    if match_group < midpoint:
                        choice_1 = match.group(match_group) + ' ' + choice_1
                        choice_2 = match.group(match_group) + ' ' + choice_2
                    elif match_group > midpoint+1:
                        choice_1 += ' ' + match.group(match_group)
                        choice_2 += ' ' + match.group(match_group)
                choice = (choice_1, choice_2)
            else:
                print('error, no value')
                choice = 'error'
            choices.append(choice)
    return choices

# %%
choices = prepare_test_data('test.txt',3)
choices
# Out:
# [('seo a dhéanann', 'seo á dhéanann'),
#  ('Timpeallachta a dhéanamh', 'Timpeallachta á dhéanamh'),
#  ('luath a dúirt', 'luath á dúirt'),
#  ('seandálaíochta a dhéanamh', 'seandálaíochta á dhéanamh'),
#  ('difriúla a aithint', 'difriúla á aithint'),
#  ('vóta a shaothraigh', 'vóta á shaothraigh'),
#  ('is a cuirtear', 'is á cuirtear'),
#  ('poiblí a bhí', 'poiblí á bhí'),
#  ('gearán a thabhairt', 'gearán á thabhairt'),
#  ('e a chur', 'e á chur'),
#  ('Chontae a threisiú\n', 'Chontae á threisiú\n'),
#  ('Veda a bheidh', 'Veda á bheidh'),
#  ('dualgais a shanntar', 'dualgais á shanntar'),
#  ('deabhal a deir', 'deabhal á deir'),
#  ('deas a tabhairt', 'deas á tabhairt'),
#  ('seo a leanas', 'seo á leanas'),
#  ("1883 a d'fhoilsigh", "1883 á d'fhoilsigh"),
#  ('atá a dhéanamh', 'atá á dhéanamh'),
#  ('Tuairisceoir a bronnadh', 'Tuairisceoir á bronnadh'),
#  ('fhorbairt a dhéanamh', 'fhorbairt á dhéanamh'),
#  ('dom a chur', 'dom á chur'),
#  ('t-urlár a ghlanadh', 't-urlár á ghlanadh'),
#  ('olltoghcháin a thuar', 'olltoghcháin á thuar'),
#  ('Níl a fhios', 'Níl á fhios'),
#  ('níl a leithéid', 'níl á leithéid'),
#  ('seo a reáchtáil', 'seo á reáchtáil'),
#  ('post a ndéantar', 'post á ndéantar'),
#  ('chaoi a ndéanfaidh', 'chaoi á ndéanfaidh'),
#  ("ea?' a déarfadh", "ea?' á déarfadh"),
#  ('scoileanna a bhí', 'scoileanna á bhí'),
#  ('seo a leanas', 'seo á leanas'),
#  ('seo a réiteach', 'seo á réiteach'),
#  ('fearr a chothú', 'fearr á chothú'),
#  ('measúnaithe a thuairisciú', 'measúnaithe á thuairisciú'),
#  ('tromchúiseacha a phlé', 'tromchúiseacha á phlé'),
#  ('Gaeilge a chur', 'Gaeilge á chur'),
#  ('fear a bhí', 'fear á bhí'),
#  ('ríomhphost a sheoladh', 'ríomhphost á sheoladh'),
#  ('r a i', 'r á i'),
#  ('rudaí a chuireann', 'rudaí á chuireann'),
#  ('as a cheannaigh', 'as á cheannaigh'),
#  ('liom a bheith', 'liom á bheith'),
#  ('thuairim a nochtadh', 'thuairim á nochtadh'),
#  ('priontaí a thaispeáint', 'priontaí á thaispeáint'),
#  ('airithe a fhreagairt', 'airithe á fhreagairt'),
#  ('éard a tuigtear', 'éard á tuigtear'),
#  ('chroí a chur', 'chroí á chur'),
#  ('mar a bhfuil', 'mar á bhfuil'),
#  ('curaclaim a bhaint', 'curaclaim á bhaint'),
#  ('íosta a a', 'íosta á a'),
#  ('ghaoth a thógáil', 'ghaoth á thógáil'),
#  ('TG4 a choimhéad', 'TG4 á choimhéad'),
#  ('nua a lorg\n', 'nua á lorg\n'),
#  ('seo a chur', 'seo á chur'),
#  ('seo a leanas', 'seo á leanas'),
#  ('tuairimí a thabhairt', 'tuairimí á thabhairt'),
#  ('tionscadal a bhuaigh', 'tionscadal á bhuaigh'),
#  ('ar a laghad', 'ar á laghad'),
#  ('féin a thugtar', 'féin á thugtar'),
#  ('é a chur', 'é á chur'),
#  ('agat a Fhiscigh', 'agat á Fhiscigh'),
#  ('gcuideachta a ionchúiseamh', 'gcuideachta á ionchúiseamh'),
#  ('fírinneach a ndéanamh', 'fírinneach á ndéanamh'),
#  ('hinniúlachtaí a thugann', 'hinniúlachtaí á thugann'),
#  ('fós a réiteach', 'fós á réiteach'),
#  ('fearr a dhéanamh', 'fearr á dhéanamh'),
#  ('oiliúint a chur', 'oiliúint á chur'),
#  ('formhór a gcuid', 'formhór á gcuid'),
#  ('sé a scríobh', 'sé á scríobh'),
#  ('ciall a bhaint', 'ciall á bhaint'),
#  ('am a chaitheamh', 'am á chaitheamh'),
#  ('ag a 400', 'ag á 400'),
#  ('ceartais a bhunú\n', 'ceartais á bhunú\n'),
#  ('líonadh a dúirt', 'líonadh á dúirt'),
#  ('€842000 a ceadaíodh', '€842000 á ceadaíodh'),
#  ('cúirte a thugann', 'cúirte á thugann'),
#  ('scoile a laghdú', 'scoile á laghdú'),
#  ('Ghaeilge a spreagadh\n', 'Ghaeilge á spreagadh\n'),
#  ('eolaíochta a rinne', 'eolaíochta á rinne'),
#  ('thar a bheith', 'thar á bheith'),
#  ('nua a bhunú?\n', 'nua á bhunú?\n'),
#  ('cosanta a dhéanamh', 'cosanta á dhéanamh'),
#  ('seo a dhéanamh', 'seo á dhéanamh'),
#  ('ginearálta a fhógróidh', 'ginearálta á fhógróidh'),
#  ('bhfírinne a rá', 'bhfírinne á rá'),
#  ('sin a athrú', 'sin á athrú'),
#  ('fiontar a bhunaigh', 'fiontar á bhunaigh'),
#  ('Nuair a bheifear', 'Nuair á bheifear'),
#  ('Mar a tharlaíonn', 'Mar á tharlaíonn'),
#  ('siar a Pháidín?', 'siar á Pháidín?'),
#  ('mar a fuair', 'mar á fuair'),
#  ('pháistí a mheas', 'pháistí á mheas'),
#  ('té a cheapfar', 'té á cheapfar'),
#  ('é a bheidh', 'é á bheidh'),
#  ('breithniú a dhéanamh', 'breithniú á dhéanamh'),
#  ('bheirt a thárlaigh', 'bheirt á thárlaigh'),
#  ('factóir a bheidh', 'factóir á bheidh'),
#  ('Nuair a fhoghlaimímid', 'Nuair á fhoghlaimímid'),
#  ('greannáin a dhéanamh', 'greannáin á dhéanamh'),
#  ('Chun a thuilleadh', 'Chun á thuilleadh'),
#  ('ar a chiontú', 'ar á chiontú'),
#  ('mó a bhfuil', 'mó á bhfuil'),
#  ('fóirsteanaí a líonfaidh', 'fóirsteanaí á líonfaidh'),
#  ('eolais a fháil', 'eolais á fháil'),
#  ('Ar a mbealach', 'Ar á mbealach'),
#  ('tuarascáil a rinne', 'tuarascáil á rinne'),
#  ('súil a choinneáil', 'súil á choinneáil'),
#  ('eagraíocht a chur', 'eagraíocht á chur'),
#  ('beocht a chur', 'beocht á chur'),
#  ('uair a chloig', 'uair á chloig'),
#  ('mar a tharlaíonn', 'mar á tharlaíonn'),
#  ('gasúr a raibh', 'gasúr á raibh'),
#  ('liom a thuigbheáil', 'liom á thuigbheáil'),
#  ('háiteacha a mbíonn', 'háiteacha á mbíonn'),
#  ('feabhas a chur', 'feabhas á chur'),
#  ("is a stóirín'", "is á stóirín'"),
#  ('fhírinne a rá', 'fhírinne á rá'),
#  ('sin a bhaineann', 'sin á bhaineann'),
#  ('ro-luath a rá', 'ro-luath á rá'),
#  ('airgid a chaitheadh', 'airgid á chaitheadh'),
#  ('argóínt a dhéanamh', 'argóínt á dhéanamh'),
#  ('ranga a bhíonn', 'ranga á bhíonn'),
#  ('Ghaelacha a chlárú', 'Ghaelacha á chlárú'),
#  ('Liathróid a rolladh', 'Liathróid á rolladh'),
#  ('mar a thaitnídís', 'mar á thaitnídís'),
#  ('chláraithe a íoslódáil', 'chláraithe á íoslódáil'),
#  ('siad a gcuid', 'siad á gcuid'),
#  ('scéal a mhíniú', 'scéal á mhíniú'),
#  ('Féinne a thabhairt', 'Féinne á thabhairt'),
#  ('seal a chaitheamh', 'seal á chaitheamh'),
#  ('gréasáin a bhuanú', 'gréasáin á bhuanú'),
#  ('atá a reáchtáil', 'atá á reáchtáil'),
#  ('Chustaiméirí a Fheabhsú', 'Chustaiméirí á Fheabhsú'),
#  ('duit a bheith', 'duit á bheith'),
#  ('sí a lámha', 'sí á lámha'),
#  ('Conamara a bhfuil', 'Conamara á bhfuil'),
#  ('spioradálta a stiúradh', 'spioradálta á stiúradh'),
#  ('Conas a rugadh', 'Conas á rugadh'),
#  ('bean a lathair', 'bean á lathair'),
#  ('mhó a bhíodh', 'mhó á bhíodh'),
#  ('nuair a mbíonn', 'nuair á mbíonn'),
#  ('iad a choinneáil', 'iad á choinneáil'),
#  ('aosta a bhí', 'aosta á bhí'),
#  ('gcoc a scaoileann', 'gcoc á scaoileann'),
#  ('ceannas a ghlacadh', 'ceannas á ghlacadh'),
#  ('orm a bheith', 'orm á bheith'),
#  ('haghaidh a riartha', 'haghaidh á riartha'),
#  ('intinne a dhéanamh', 'intinne á dhéanamh'),
#  ('wwwscsie a chuireann', 'wwwscsie á chuireann'),
#  ('iad a úsáid', 'iad á úsáid'),
#  ('corpraithe a díscaoileadh', 'corpraithe á díscaoileadh'),
#  ('eile a bheadh', 'eile á bheadh'),
#  ('móin a thugas', 'móin á thugas'),
#  ('rud a chuimsíonn', 'rud á chuimsíonn'),
#  ('léir a bheidh', 'léir á bheidh'),
#  ('costas a íoc', 'costas á íoc'),
#  ('daoine a bhí', 'daoine á bhí'),
#  ('moladh a \n', 'moladh á \n'),
#  ('sonraithe a íoc', 'sonraithe á íoc'),
#  ('t-eolas a fuarthas', 't-eolas á fuarthas'),
#  ('Mhainnínigh a rugadh', 'Mhainnínigh á rugadh'),
#  ('#election2012 a leanúint', '#election2012 á leanúint'),
#  ('siad a mian\n', 'siad á mian\n'),
#  ("B'ansin a neartaigh", "B'ansin á neartaigh"),
#  ('fíor a chara', 'fíor á chara'),
#  ('Athchóirithe a thug', 'Athchóirithe á thug'),
#  ('Cé a cuimhníonn', 'Cé á cuimhníonn'),
#  ('fearr a bhíonn', 'fearr á bhíonn'),
#  ('Cead a bhaineann', 'Cead á bhaineann'),
#  ('féidir a ríomh', 'féidir á ríomh'),
#  ('bhfuil a fhios', 'bhfuil á fhios'),
#  ('@LiamPort a very', '@LiamPort á very'),
#  ('fhaisnéis a nochtadh', 'fhaisnéis á nochtadh'),
#  ('contae a bhfuil', 'contae á bhfuil'),
#  ('fadhbanna a bheith', 'fadhbanna á bheith'),
#  ('t-ordú a dhéanamh', 't-ordú á dhéanamh'),
#  ('drochthoradh a thiocfaidh', 'drochthoradh á thiocfaidh'),
#  ('DMS a thabhairt', 'DMS á thabhairt'),
#  ('dlí a bheith', 'dlí á bheith'),
#  ('linn a rá', 'linn á rá'),
#  ('mar a fhaigheann', 'mar á fhaigheann'),
#  ('cumasacha a bhfuil', 'cumasacha á bhfuil'),
#  ('fáil a bhain', 'fáil á bhain'),
#  ('plé a dhéanamh', 'plé á dhéanamh'),
#  ('féin a choinneáil', 'féin á choinneáil'),
#  ('pinn a ghlanadh\n', 'pinn á ghlanadh\n'),
#  ('libh a bheith', 'libh á bheith'),
#  ('rud a aontaíonn', 'rud á aontaíonn'),
#  ('mhír a bhí', 'mhír á bhí'),
#  ('mar a scríobh', 'mar á scríobh'),
#  ('saol a blaiseadh', 'saol á blaiseadh'),
#  ('áirithe a thabhairt', 'áirithe á thabhairt'),
#  ('dánta a gceol', 'dánta á gceol'),
#  ('tithíochta a bhíonn', 'tithíochta á bhíonn'),
#  ('leo a fháil', 'leo á fháil'),
#  ('íocaíocht a sheoladh', 'íocaíocht á sheoladh'),
#  ('iarratas a bheith', 'iarratas á bheith'),
#  ('ríomhPharlaiminte a chur', 'ríomhPharlaiminte á chur'),
#  ('mó a bhí', 'mó á bhí'),
#  ('dteaghlaigh a smachtú', 'dteaghlaigh á smachtú'),
#  ('tarraingím a lán', 'tarraingím á lán'),
#  ('AE a chur', 'AE á chur'),
#  ('éifeacht a bheadh', 'éifeacht á bheadh'),
#  ('cásanna a éireoidh', 'cásanna á éireoidh'),
#  ('dul a thuilleadh\n', 'dul á thuilleadh\n'),
#  ('leis a bhfuil', 'leis á bhfuil'),
#  ('Seanchéibhe a aimsíodh', 'Seanchéibhe á aimsíodh'),
#  ('seo a ghlanadh', 'seo á ghlanadh'),
#  ('fear a bhí', 'fear á bhí'),
#  ('mó a bhfaca', 'mó á bhfaca'),
#  ('deontais a thabhairt', 'deontais á thabhairt'),
#  ('comhairle a thabhairt', 'comhairle á thabhairt'),
#  ('Jackson a bheas', 'Jackson á bheas'),
#  ('tú a iarraidh', 'tú á iarraidh'),
#  ('cheant a bhí', 'cheant á bhí'),
#  ('tionchar a bhí', 'tionchar á bhí'),
#  ('ais a luaithe', 'ais á luaithe'),
#  ('anois a dhéanfaidh', 'anois á dhéanfaidh'),
#  ('Bainistíochta a cur', 'Bainistíochta á cur'),
#  ('míréasúnta a dhéanamh', 'míréasúnta á dhéanamh'),
#  ('inbhuanaithe a chur', 'inbhuanaithe á chur'),
#  ('ndlínse a bhfuil', 'ndlínse á bhfuil'),
#  ('dteach a sheanmháthar', 'dteach á sheanmháthar'),
#  ('leathnú a dhéanamh', 'leathnú á dhéanamh'),
#  ('liteartha a thagann', 'liteartha á thagann'),
#  ('chun a gcuid', 'chun á gcuid'),
#  ('é a chimiú', 'é á chimiú'),
#  ('beag a thabhairt', 'beag á thabhairt'),
#  ('Nuair a chuirfear', 'Nuair á chuirfear'),
#  ('Tá a áit', 'Tá á áit'),
#  ('duine a choinneáil', 'duine á choinneáil'),
#  ('leictriceimice a dhéanamh', 'leictriceimice á dhéanamh'),
#  ('súil a thabhairt', 'súil á thabhairt'),
#  ('Normannach a tógadh', 'Normannach á tógadh'),
#  ('achomharc a dhéanamh', 'achomharc á dhéanamh'),
#  ('foráil a dhéanamh', 'foráil á dhéanamh'),
#  ('mar a dúirt', 'mar á dúirt'),
#  ('gcinnteoireacht a bhíonn', 'gcinnteoireacht á bhíonn'),
#  ('cartúin a dtarraingt', 'cartúin á dtarraingt'),
#  ('duine a fháil', 'duine á fháil'),
#  ('é a a', 'é á a'),
#  ('oideachais a cur', 'oideachais á cur'),
#  ('scaireanna a thairiscint', 'scaireanna á thairiscint'),
#  ('nGaeilge a ardú', 'nGaeilge á ardú'),
#  ('míniú a thabhairt', 'míniú á thabhairt'),
#  ('taifeadta a thiomsú', 'taifeadta á thiomsú'),
#  ('Éifeacht a thabhairt', 'Éifeacht á thabhairt'),
#  ('ar a laghad', 'ar á laghad'),
#  ('ghníomhartha a ghlacadh', 'ghníomhartha á ghlacadh'),
#  ('iarratais a iarraidh', 'iarratais á iarraidh'),
#  ('láimhe a thiontú', 'láimhe á thiontú'),
#  ('céanna a bhí', 'céanna á bhí'),
#  ('deireadh a chuir', 'deireadh á chuir'),
#  ('Cad a bheidh', 'Cad á bheidh'),
#  ('fuar a mbeadh', 'fuar á mbeadh'),
#  ('fáth a bhfuil', 'fáth á bhfuil'),
#  ('rith a dhéanamh', 'rith á dhéanamh'),
#  ('cé a gheobhaidh', 'cé á gheobhaidh'),
#  ('crainn a chuireann', 'crainn á chuireann'),
#  ('nua a bheidh', 'nua á bheidh'),
#  ('cruinn a thuilleadh\n', 'cruinn á thuilleadh\n'),
#  ('Nuair a fuair', 'Nuair á fuair'),
#  ('seo a úsáid', 'seo á úsáid'),
#  ('saol a bhainfeadh', 'saol á bhainfeadh'),
#  ('Gaeilge a sholáthar', 'Gaeilge á sholáthar'),
#  ('mar a bhí', 'mar á bhí'),
#  ('mó a bheith', 'mó á bheith'),
#  ('fheirme a bhí', 'fheirme á bhí'),
#  ('droma a ghobann', 'droma á ghobann'),
#  ('séarachais a bhunú', 'séarachais á bhunú'),
#  ('iarraidh a chur', 'iarraidh á chur'),
#  ('Ospidéil a Bhunú', 'Ospidéil á Bhunú'),
#  ('slán a dhéanamh', 'slán á dhéanamh'),
#  ('féinne a thabhairt', 'féinne á thabhairt'),
#  ('raibh a bhformhór', 'raibh á bhformhór'),
#  ("scoile a d'imir", "scoile á d'imir"),
#  ('cartlanna a bhaint', 'cartlanna á bhaint'),
#  ('bric a dhíol', 'bric á dhíol'),
#  ('Liospóin a síníodh', 'Liospóin á síníodh'),
#  ('amhlaidh a shonraigh', 'amhlaidh á shonraigh'),
#  ('Cad a chuireann', 'Cad á chuireann'),
#  ('leith a p(h)íosaí', 'leith á p(h)íosaí'),
#  ('teanga a fhoghlaim', 'teanga á fhoghlaim'),
#  ('sin a chomhlíonadh\n', 'sin á chomhlíonadh\n'),
#  ('mó a thugann', 'mó á thugann'),
#  ('difriúla a bheidh', 'difriúla á bheidh'),
#  ('seasta a chur', 'seasta á chur'),
#  ('2003 a bunaíodh', '2003 á bunaíodh'),
#  ('eile a dhéanfaidh', 'eile á dhéanfaidh'),
#  ('daoine a náiriú', 'daoine á náiriú'),
#  ('Grífín a scóráil', 'Grífín á scóráil'),
#  ('dóchas a bhí', 'dóchas á bhí'),
#  ('aistriúcháin a bhí', 'aistriúcháin á bhí'),
#  ('greim a choimeád', 'greim á choimeád'),
#  ('líomhaintí a deineadh', 'líomhaintí á deineadh'),
#  ('saoi) a leanacht', 'saoi) á leanacht'),
#  ('Eorpach a chuireann', 'Eorpach á chuireann'),
#  ('léargas a thugann', 'léargas á thugann'),
#  ('atá a léiriú', 'atá á léiriú'),
#  ('bhoth a bhí', 'bhoth á bhí'),
#  ('mó a bheith', 'mó á bheith'),
#  ('fada a úsáidtear', 'fada á úsáidtear'),
#  ('sonraí a stóráil', 'sonraí á stóráil'),
#  ('seo a eagrú', 'seo á eagrú'),
#  ('mór a bheith', 'mór á bheith'),
#  ('deonacha a lorg', 'deonacha á lorg'),
#  ('amháin a cheannach\n', 'amháin á cheannach\n'),
#  ('poiblí a bheith', 'poiblí á bheith'),
#  ('ardchaighdeáin a sholáthar', 'ardchaighdeáin á sholáthar'),
#  ('nuair a rinne', 'nuair á rinne'),
#  ('heachtraí a bhain', 'heachtraí á bhain'),
#  ('seo a dhéanann', 'seo á dhéanann'),
#  ('atá a dhíth\n', 'atá á dhíth\n'),
#  ('anuas a tháinig', 'anuas á tháinig'),
#  ('é a fhágáil', 'é á fhágáil'),
#  ('ach a bhfuil', 'ach á bhfuil'),
#  ('tacaíocht a sheachadadh', 'tacaíocht á sheachadadh'),
#  ('barr a shroiceadh', 'barr á shroiceadh'),
#  ('tá a lán', 'tá á lán'),
#  ('ar a gcuid', 'ar á gcuid'),
#  ('leana a leithéid', 'leana á leithéid'),
#  ('cinneadh a dhéanamh', 'cinneadh á dhéanamh'),
#  ('seo a leanas', 'seo á leanas'),
#  ('tá a fhios', 'tá á fhios'),
#  ('sceimhle a bhaineann', 'sceimhle á bhaineann'),
#  ('chraic a bhain', 'chraic á bhain'),
#  ('bhreith a thug', 'bhreith á thug'),
#  ('ort a léitheoir\n', 'ort á léitheoir\n'),
#  ('tuairisceoireacht a dhéanamh', 'tuairisceoireacht á dhéanamh'),
#  ('iarratas a lorg', 'iarratas á lorg'),
#  ('é a leigheas\n', 'é á leigheas\n'),
#  ('ceisteanna a bhaineann', 'ceisteanna á bhaineann'),
#  ('iad a bheith', 'iad á bheith'),
#  ('í a thoghfar', 'í á thoghfar'),
#  ('achomharc a dhéanamh', 'achomharc á dhéanamh'),
#  ('eile a bhféadfadh', 'eile á bhféadfadh'),
#  ('sean-Éireann a bhfuascailt', 'sean-Éireann á bhfuascailt'),
#  ('dheamhan a lúbfadh', 'dheamhan á lúbfadh'),
#  ('choíche a shíl', 'choíche á shíl'),
#  ('scoileanna a dhíríonn', 'scoileanna á dhíríonn'),
#  ("Duibhe' a bhí", "Duibhe' á bhí"),
#  ('ama a léiríonn', 'ama á léiríonn'),
#  ('é a bheith', 'é á bheith'),
#  ('Shonraí a Athrú', 'Shonraí á Athrú'),
#  ('áitiúla a dhéanamh', 'áitiúla á dhéanamh'),
#  ('mbillí a íoc\n', 'mbillí á íoc\n'),
#  ('bhí a bhás', 'bhí á bhás'),
#  ('tú a cheangal', 'tú á cheangal'),
#  ('scairdeadh a srutha', 'scairdeadh á srutha'),
#  ('iomlán a dhéanamh', 'iomlán á dhéanamh'),
#  ('23 a léirmhíniú', '23 á léirmhíniú'),
#  ("bpáistí a d'fhreastail", "bpáistí á d'fhreastail"),
#  ('daoine a bhfuil', 'daoine á bhfuil'),
#  ('ar a bhfuil', 'ar á bhfuil'),
#  ('n-imirceach a thug', 'n-imirceach á thug'),
#  ('oibreacha a chur', 'oibreacha á chur'),
#  ('nasc a dhéanamh', 'nasc á dhéanamh'),
#  ('sin a chloisteáil', 'sin á chloisteáil'),
#  ('caipitil a sonraítear', 'caipitil á sonraítear'),
#  ('is a bhíomar', 'is á bhíomar'),
#  ('Ús a híocadh', 'Ús á híocadh'),
#  ('Oidhreacht a sciar', 'Oidhreacht á sciar'),
#  ('nuair a dhéanfidh', 'nuair á dhéanfidh'),
#  ('daoine a cheapadh', 'daoine á cheapadh'),
#  ('fhorbairt a údaraíodh', 'fhorbairt á údaraíodh'),
#  ('atá a fhios', 'atá á fhios'),
#  ('daoine a bhfuil', 'daoine á bhfuil'),
#  ('seo a bhaint', 'seo á bhaint'),
#  ('casaoidí a bhaineann', 'casaoidí á bhaineann'),
#  ('Chonghaile a reáchtáil', 'Chonghaile á reáchtáil'),
#  ('tionchar a bhíonn', 'tionchar á bhíonn'),
#  ('treallamh a chuireann', 'treallamh á chuireann'),
#  ('mhír a gcomhlíonadh', 'mhír á gcomhlíonadh'),
#  ('éinne a choimeád', 'éinne á choimeád'),
#  ('mbárr a réime', 'mbárr á réime'),
#  ('Bhí a fhios', 'Bhí á fhios'),
#  ('tú a dhéanamh', 'tú á dhéanamh'),
#  ('Éireann a bheith', 'Éireann á bheith'),
#  ('seo a leanas', 'seo á leanas'),
#  ('iad a liostú', 'iad á liostú'),
#  ('haontachta a oscailt\n', 'haontachta á oscailt\n'),
#  ('struchtúir a rialaíonn', 'struchtúir á rialaíonn'),
#  ('seachas a ndisciplín', 'seachas á ndisciplín'),
#  ('rud a bheadh', 'rud á bheadh'),
#  ('di a cuid', 'di á cuid'),
#  ('tréimhse a chuir', 'tréimhse á chuir'),
#  ('troid a rinne', 'troid á rinne'),
#  ('ghlas a chur', 'ghlas á chur'),
#  ('talaimh a cheannach', 'talaimh á cheannach'),
#  ('sin a fháil', 'sin á fháil'),
#  ('–POD a réamhphobalú', '–POD á réamhphobalú'),
#  ('ann a dhéanann', 'ann á dhéanann'),
#  ('haiseolas a thabhairt', 'haiseolas á thabhairt'),
#  ('teachtaireacht a thagann', 'teachtaireacht á thagann'),
#  ('nuair a thiocfaimid', 'nuair á thiocfaimid'),
#  ('deighilt a bhí', 'deighilt á bhí'),
#  ('ábhartha a thabhairt', 'ábhartha á thabhairt'),
#  ('himreoirí a ghlac', 'himreoirí á ghlac'),
#  ('riachtanas a chlúdach', 'riachtanas á chlúdach'),
#  ('cad a ghearrtar', 'cad á ghearrtar'),
#  ('Spáinn a thuill', 'Spáinn á thuill'),
#  ('freastalaithe a chur', 'freastalaithe á chur'),
#  ('nuair a bheimid', 'nuair á bheimid'),
#  ('beag a bhí', 'beag á bhí'),
#  ('mar a thagann', 'mar á thagann'),
#  ('athbhreithniú a dhéanamh', 'athbhreithniú á dhéanamh'),
#  ('gníomhaíochtaí a bhaineann', 'gníomhaíochtaí á bhaineann'),
#  ('é a bhfuil', 'é á bhfuil'),
#  ('sainmhíniú a dhéanamh', 'sainmhíniú á dhéanamh'),
#  ('reachtúil a bhaineann', 'reachtúil á bhaineann'),
#  ('Grma a Sheosaimh', 'Grma á Sheosaimh'),
#  ('dóigh a ndéanfaí', 'dóigh á ndéanfaí'),
#  ('teolas a bhí', 'teolas á bhí'),
#  ('Duine a dhlífidh', 'Duine á dhlífidh'),
#  ('beart a dhéanamh!\n', 'beart á dhéanamh!\n'),
#  ('é a chreidiúint', 'é á chreidiúint'),
#  ('áit a bhfuil', 'áit á bhfuil'),
#  ('Mar a chruthaíonn', 'Mar á chruthaíonn'),
#  ('Teanga a spreagann', 'Teanga á spreagann'),
#  ('seo a léamh', 'seo á léamh'),
#  ('eolas a bheith', 'eolas á bheith'),
#  ('nuair a bhíodh', 'nuair á bhíodh'),
#  ('pháiste a réamhrollú', 'pháiste á réamhrollú'),
#  ('duit a bheith', 'duit á bheith'),
#  ('nóiméad a sroichfidh', 'nóiméad á sroichfidh'),
#  ('Bliain a hAon', 'Bliain á hAon'),
#  ('mhó a tharraing', 'mhó á tharraing'),
#  ('chuideachta a thabhairt', 'chuideachta á thabhairt'),
#  ('Caithfear a chur', 'Caithfear á chur'),
#  ('Gaotha a shéideann', 'Gaotha á shéideann'),
#  ('Romaigh a Bhunú', 'Romaigh á Bhunú'),
#  ('chuige a bhfuil', 'chuige á bhfuil'),
#  ('ar a anam', 'ar á anam'),
#  ('toghcháin a sholáthar', 'toghcháin á sholáthar'),
#  ('seo a leanas', 'seo á leanas'),
#  ('Nuair a tugadh', 'Nuair á tugadh'),
#  ('cinneadh a dhéanamh', 'cinneadh á dhéanamh'),
#  ('2002 a bheadh', '2002 á bheadh'),
#  ('ann a thabharfadh', 'ann á thabharfadh'),
#  ('chor a bheith', 'chor á bheith'),
#  ('fios a bheith', 'fios á bheith'),
#  ('é a mhínigh', 'é á mhínigh'),
#  ('iarratais a sheoladh', 'iarratais á sheoladh'),
#  ('leo a bheith', 'leo á bheith'),
#  ('ann a insíonn', 'ann á insíonn'),
#  ('béil a thaifeadadh', 'béil á thaifeadadh'),
#  ('Comhrá a trí', 'Comhrá á trí'),
#  ('Mar a deir', 'Mar á deir'),
#  ('airneáil a dhéanamh', 'airneáil á dhéanamh'),
#  ('foráil a áireamh', 'foráil á áireamh'),
#  ('t-ábhar a chur', 't-ábhar á chur'),
#  ('Maryland a tharraing', 'Maryland á tharraing'),
#  ('nóiméad a fhilleann', 'nóiméad á fhilleann'),
#  ('nuair a thiocfaidh', 'nuair á thiocfaidh'),
#  ('Mar a thaispeántar', 'Mar á thaispeántar'),
#  ('treanála a thaispeann', 'treanála á thaispeann'),
#  ('agus a gcairde', 'agus á gcairde'),
#  ('ar a laghad', 'ar á laghad'),
#  ('ballraiocht a ghlacadh', 'ballraiocht á ghlacadh'),
#  ('maitheamh a fháil', 'maitheamh á fháil'),
#  ('fheidhm a bheith', 'fheidhm á bheith'),
#  ('bpátrún a bhí', 'bpátrún á bhí'),
#  ('mar a léirítear', 'mar á léirítear'),
#  ('leat a Phia\n', 'leat á Phia\n'),
#  ('hipitéis a bhfuil', 'hipitéis á bhfuil'),
#  ('ar a gcosa\n', 'ar á gcosa\n'),
#  ('Nuair a shroichfeas', 'Nuair á shroichfeas'),
#  ('díreach a bhí', 'díreach á bhí'),
#  ('cheart a thabhairt', 'cheart á thabhairt'),
#  ('thú a Thomáis', 'thú á Thomáis'),
#  ('tacaíocht a bhí', 'tacaíocht á bhí'),
#  ('fiche a dó\n', 'fiche á dó\n'),
#  ('dhaoine a chreideann', 'dhaoine á chreideann'),
#  ('mise a smaoineamh', 'mise á smaoineamh'),
#  ('duine a cheapfaidh', 'duine á cheapfaidh'),
#  ('mórimpleachtaí a bheith', 'mórimpleachtaí á bheith'),
#  ('sí a rinn', 'sí á rinn'),
#  ('scoileanna a ndícheall', 'scoileanna á ndícheall'),
#  ('mar a fheidhmíonn', 'mar á fheidhmíonn'),
#  ('cruth a thabhairt', 'cruth á thabhairt'),
#  ('maoine a dhéantar', 'maoine á dhéantar'),
#  ('seo a leasú', 'seo á leasú'),
#  ('dramhaíola a leagan', 'dramhaíola á leagan'),
#  ('nuair a bhíonn', 'nuair á bhíonn'),
#  ('méid a bhí', 'méid á bhí'),
#  ('neamhláithreacht a tharlaíonn', 'neamhláithreacht á tharlaíonn'),
#  ('fhormáid a bheidh', 'fhormáid á bheidh'),
#  ('Aaron a chur', 'Aaron á chur'),
#  ('twitter a Bhodach!!!', 'twitter á Bhodach!!!'),
#  ('réir a thola', 'réir á thola'),
#  ('réiteach a fháil', 'réiteach á fháil'),
#  ('eile a chonaic', 'eile á chonaic'),
#  ('Conas a bheith', 'Conas á bheith'),
#  ('rothaíochta a dhéanamh', 'rothaíochta á dhéanamh'),
#  ('eagraithe a bhí', 'eagraithe á bhí'),
#  ('beirt a leanúint', 'beirt á leanúint'),
#  ('thoil a deir', 'thoil á deir'),
#  ('cé a sceith', 'cé á sceith'),
#  ('dtús a chiallaíonn', 'dtús á chiallaíonn'),
#  ('ar a fhíorathair', 'ar á fhíorathair'),
#  ('Anois a loig', 'Anois á loig'),
#  ('Tríd a gceoig', 'Tríd á gceoig'),
#  ('muid a dhéanamh', 'muid á dhéanamh'),
#  ('chor a bheith', 'chor á bheith'),
#  ('foráil a dhéanamh', 'foráil á dhéanamh'),
#  ('Paco a bhealach', 'Paco á bhealach'),
#  ('leasaithe a líonadh', 'leasaithe á líonadh'),
#  ('sonraí a chur', 'sonraí á chur'),
#  ('chaoi a bhfuil', 'chaoi á bhfuil'),
#  ('leithéid a chur', 'leithéid á chur'),
#  ('fearr a fhorbairt', 'fearr á fhorbairt'),
#  ('lón a chaitheamh\n', 'lón á chaitheamh\n'),
#  ('ardoideachas a chur', 'ardoideachas á chur'),
#  ('costas a bhaineann', 'costas á bhaineann'),
#  ('mé a shuaimhniú', 'mé á shuaimhniú'),
#  ('nuair a bhítear', 'nuair á bhítear'),
#  ('rabóid a chuir', 'rabóid á chuir'),
#  ('ar a dhúchas', 'ar á dhúchas'),
#  ('eile a chuirfidh', 'eile á chuirfidh'),
#  ('Gnásanna a léiríonn', 'Gnásanna á léiríonn'),
#  ('Ceist a hAon\n', 'Ceist á hAon\n'),
#  ('mholtaí a chuirfear', 'mholtaí á chuirfear'),
#  ('Teanga a bheadh', 'Teanga á bheadh'),
#  ('Nuair a chluinim', 'Nuair á chluinim'),
#  ('ar a leabhar', 'ar á leabhar'),
#  ('tábhachtach a thabhairt', 'tábhachtach á thabhairt'),
#  ('tréimhse a chaith', 'tréimhse á chaith'),
#  ('bpáistí a fheiceáil', 'bpáistí á fheiceáil'),
#  ('tátal a bhaintear', 'tátal á bhaintear'),
#  ('Lúnasa a cháin', 'Lúnasa á cháin'),
#  ('Árainn a thóg', 'Árainn á thóg'),
#  ('reifrinn a leagan', 'reifrinn á leagan'),
#  ('teanga a fhoghlaim;', 'teanga á fhoghlaim;'),
#  ('shaothraigh a gcuid', 'shaothraigh á gcuid'),
#  ('leat a ithe\n', 'leat á ithe\n'),
#  ('sin a thógfar', 'sin á thógfar'),
#  ('tús a chur', 'tús á chur'),
#  ('Gaeilge a aistriu', 'Gaeilge á aistriu'),
#  ('páiste a chothú', 'páiste á chothú'),
#  ('creat a bhunú', 'creat á bhunú'),
#  ('féin a chur', 'féin á chur'),
#  ("múinte a d'fhéach", "múinte á d'fhéach"),
#  ('acmhainní a fhorbairt', 'acmhainní á fhorbairt'),
#  ('sheachtracha a chruthútá', 'sheachtracha á chruthútá'),
#  ('tábhachtacha a bheith', 'tábhachtacha á bheith'),
#  ('éard a bheidh', 'éard á bheidh'),
#  ('teanga a chraobhscaoileadh', 'teanga á chraobhscaoileadh'),
#  ('nua a mholadh', 'nua á mholadh'),
#  ('as a leaba', 'as á leaba'),
#  ('ag a dheirfiúr\n', 'ag á dheirfiúr\n'),
#  ('Ghaeilge a húsáid', 'Ghaeilge á húsáid'),
#  ('seo a thagann', 'seo á thagann'),
#  ('nuair a bhain', 'nuair á bhain'),
#  ('thar a chéile\n', 'thar á chéile\n'),
#  ('fuinneamh a tháirgiú', 'fuinneamh á tháirgiú'),
#  ('aitheantais a scríobhtar', 'aitheantais á scríobhtar'),
#  ('ndúnmharú a deir', 'ndúnmharú á deir'),
#  ('ann a bhí', 'ann á bhí'),
#  ('Eo a bpasáiste', 'Eo á bpasáiste'),
#  ('áirithe a leithéad', 'áirithe á leithéad'),
#  ('cake a bhuachaill', 'cake á bhuachaill'),
#  ('chaint a bhíonn', 'chaint á bhíonn'),
#  ('hiad a cuireadh', 'hiad á cuireadh'),
#  ('coinníollacha a bhaineann', 'coinníollacha á bhaineann'),
#  ('tú a fheiscint', 'tú á fheiscint'),
#  ('chéanna a dhéanamh', 'chéanna á dhéanamh'),
#  ("Comhairle a d'fheidhmigh", "Comhairle á d'fheidhmigh"),
#  ('sin a chairde', 'sin á chairde'),
#  ('mhaith a máthair', 'mhaith á máthair'),
#  ('Ránais a bhíonn', 'Ránais á bhíonn'),
#  ('thart a dhéanamh', 'thart á dhéanamh'),
#  ('agus a thionlacan', 'agus á thionlacan'),
#  ("Conas a d'éirigh", "Conas á d'éirigh"),
#  ('moltaí a dhéanamh\n', 'moltaí á dhéanamh\n'),
#  ('Tá a fhios', 'Tá á fhios'),
#  ('Riarthóir a chur', 'Riarthóir á chur'),
#  ('imeachta a bhunú', 'imeachta á bhunú'),
#  ('nGaillimh a shásaigh', 'nGaillimh á shásaigh'),
#  ('roimh a chraolta', 'roimh á chraolta'),
#  ('Aontaithe a thuiscint', 'Aontaithe á thuiscint'),
#  ('iarratas a dhéanamh', 'iarratas á dhéanamh'),
#  ('é a réitíonn', 'é á réitíonn'),
#  ('seo a thuiscint\n', 'seo á thuiscint\n'),
#  ('áirithe a ríomh\n', 'áirithe á ríomh\n'),
#  ('tseirbhís a fhágann', 'tseirbhís á fhágann'),
#  ('leaba a fháil', 'leaba á fháil'),
#  ('deiseanna a chur', 'deiseanna á chur'),
#  ('tionscadal a dhéanfar', 'tionscadal á dhéanfar'),
#  ('féin a bhí', 'féin á bhí'),
#  ('scéal a ghoill', 'scéal á ghoill'),
#  ('Mar a chéile', 'Mar á chéile'),
#  ('é a n-údar', 'é á n-údar'),
#  ('aibítir a úsáideann', 'aibítir á úsáideann'),
#  ('faisnéise a aistreoidh', 'faisnéise á aistreoidh'),
#  ('deireadh a chur', 'deireadh á chur'),
#  ('uaitse a Athair', 'uaitse á Athair'),
#  ('raghadh a chodladh', 'raghadh á chodladh'),
#  ('formhór a raibh', 'formhór á raibh'),
#  ('stealladh a raibh', 'stealladh á raibh'),
#  ('chinneadh a chabhródh', 'chinneadh á chabhródh'),
#  ('1971 a tharraing', '1971 á tharraing'),
#  ('leabhar a thabhairt', 'leabhar á thabhairt'),
#  ('rang a sé', 'rang á sé'),
#  ('Nuair a bhaintear', 'Nuair á bhaintear'),
#  ('Coll a dhaoradh', 'Coll á dhaoradh'),
#  ('bharr a teaspántas', 'bharr á teaspántas'),
#  ('Bhreisluacha a bhaint', 'Bhreisluacha á bhaint'),
#  ('loch a bhí', 'loch á bhí'),
#  ('Seosamh a athair', 'Seosamh á athair'),
#  ('óir a deir', 'óir á deir'),
#  ('mar a bhainim', 'mar á bhainim'),
#  ('acu a fuaireas', 'acu á fuaireas'),
#  ('thuras a bhí', 'thuras á bhí'),
#  ('deis a thabhairt', 'deis á thabhairt'),
#  ('méid a thuigeann', 'méid á thuigeann'),
#  ('Nuair a bhí', 'Nuair á bhí'),
#  ('raibh a bhata', 'raibh á bhata'),
#  ('imshaol a thuiscint', 'imshaol á thuiscint'),
#  ('ag a deireadh', 'ag á deireadh'),
#  ('é a chuir', 'é á chuir'),
#  ('cuí a dhéanamh', 'cuí á dhéanamh'),
#  ('athbhreithniú a dhéanamh', 'athbhreithniú á dhéanamh'),
#  ('Scoile a fhorfheidhmiú\n', 'Scoile á fhorfheidhmiú\n'),
#  ('suimeanna a bheidh', 'suimeanna á bheidh'),
#  ('Nuair a bhuailim', 'Nuair á bhuailim'),
#  ('linn a óige', 'linn á óige'),
#  ('Filíochta a thugaidís', 'Filíochta á thugaidís'),
#  ('Eabharc a chumadh', 'Eabharc á chumadh'),
#  ('dóibh a mbreithiúnas', 'dóibh á mbreithiúnas'),
#  ('minic a fheidhmítear', 'minic á fheidhmítear'),
#  ('Tuaiscirt a fhágáil', 'Tuaiscirt á fhágáil'),
#  ('spinéad a bhí', 'spinéad á bhí'),
#  ('dearca a bheadh', 'dearca á bheadh'),
#  ('fhaisnéis a thabharfar', 'fhaisnéis á thabharfar'),
#  ('scéil a nochtadh\n', 'scéil á nochtadh\n'),
#  ('maisín a dhéanamh', 'maisín á dhéanamh'),
#  ('leanúnach a chur', 'leanúnach á chur'),
#  ('ag a fear', 'ag á fear'),
#  ('gcúl a chleachtadh', 'gcúl á chleachtadh'),
#  ('duine a thabharfaidh', 'duine á thabharfaidh'),
#  ('anois a oibreoidh', 'anois á oibreoidh'),
#  ('socruithe a ndéanamh', 'socruithe á ndéanamh'),
#  ('hoifigigh a toghadh', 'hoifigigh á toghadh'),
#  ('éard a deir', 'éard á deir'),
#  ('mar a luaigh', 'mar á luaigh'),
#  ('dalla a dhéanann', 'dalla á dhéanann'),
#  ('Feirste a bhfuil', 'Feirste á bhfuil'),
#  ('Seo a cuntas', 'Seo á cuntas'),
#  ('ionadaíocht a dhéanamh', 'ionadaíocht á dhéanamh'),
#  ('ar a gcuid', 'ar á gcuid'),
#  ('filíochta a fhoilsiú', 'filíochta á fhoilsiú'),
#  ('scrúdaithe a dhéanamh', 'scrúdaithe á dhéanamh'),
#  ('Ghaeilge a bheith', 'Ghaeilge á bheith'),
#  ('ar a laghad\n', 'ar á laghad\n'),
#  ('suntasach a bhí', 'suntasach á bhí'),
#  ('FIT a fháil', 'FIT á fháil'),
#  ('ar a bhfuil', 'ar á bhfuil'),
#  ('sin a tharraingt', 'sin á tharraingt'),
#  ('tine a bheith', 'tine á bheith'),
#  ('amhras a sheachaint', 'amhras á sheachaint'),
#  ('ceiliúradh a dhéanamh', 'ceiliúradh á dhéanamh'),
#  ('tseanscéim a bhí', 'tseanscéim á bhí'),
#  ('tíre a bheidh', 'tíre á bheidh'),
#  ('t-airgead a bheidh', 't-airgead á bheidh'),
#  ('tús a chur', 'tús á chur'),
#  ('sláinte a aisíoc', 'sláinte á aisíoc'),
#  ("réimsí a d'fhéadfaí", "réimsí á d'fhéadfaí"),
#  ('nuair a chuaigh', 'nuair á chuaigh'),
#  ('seo a shamhlú', 'seo á shamhlú'),
#  ('daoine a cheistiú', 'daoine á cheistiú'),
#  ('leat a rá', 'leat á rá'),
#  ('ceart a fháil', 'ceart á fháil'),
#  ('beag a thabhairt', 'beag á thabhairt'),
#  ('gradam a thabharfaidh', 'gradam á thabharfaidh'),
#  ('é a thionscnamh', 'é á thionscnamh'),
#  ('Gaeilge a chuimseoidh', 'Gaeilge á chuimseoidh'),
#  ('raibh a mac', 'raibh á mac'),
#  ('chun a n-ionad', 'chun á n-ionad'),
#  ('éigin a mhúsclódh', 'éigin á mhúsclódh'),
#  ('staidéar a dhéanamh', 'staidéar á dhéanamh'),
#  ('athbhreithniú a dhéanamh', 'athbhreithniú á dhéanamh'),
#  ('diabhail a bheith', 'diabhail á bheith'),
#  ('Aontaithe a bunaíodh', 'Aontaithe á bunaíodh'),
#  ('atá a stiúradh', 'atá á stiúradh'),
#  ('casadhmaid a bhí', 'casadhmaid á bhí'),
#  ('thar a n-urnaithe', 'thar á n-urnaithe'),
#  ('ar a laghad', 'ar á laghad'),
#  ('morgáiste a éileamh', 'morgáiste á éileamh'),
#  ('thar a bheith', 'thar á bheith'),
#  ('ar a dtugtar', 'ar á dtugtar'),
#  ('nó a bhaineann', 'nó á bhaineann'),
#  ('Debian a fhorbairt', 'Debian á fhorbairt'),
#  ('phearsanta a thabhairt', 'phearsanta á thabhairt'),
#  ('ealaíne a chur', 'ealaíne á chur'),
#  ('nuair a Salle', 'nuair á Salle'),
#  ('airgead a mhalartú', 'airgead á mhalartú'),
#  ('bhunaidh a ghabhann', 'bhunaidh á ghabhann'),
#  ('faoi a chloisteáil\n', 'faoi á chloisteáil\n'),
#  ('socraíochta a rinneadh', 'socraíochta á rinneadh'),
#  ('daoine a tógadh', 'daoine á tógadh'),
#  ('díreach a thabhairt', 'díreach á thabhairt'),
#  ('bith a chaithfidh', 'bith á chaithfidh'),
#  ('Caithfimid a chinntiú', 'Caithfimid á chinntiú'),
#  ('gairid a deir', 'gairid á deir'),
#  ('scrúdú a dhéanamh', 'scrúdú á dhéanamh'),
#  ('mhaoin a bhfuil', 'mhaoin á bhfuil'),
#  ('seo a bhailiú', 'seo á bhailiú'),
#  ('gairneoireachta a mhéadú', 'gairneoireachta á mhéadú'),
#  ('phaisinéara a dúradh', 'phaisinéara á dúradh'),
#  ('(1750–1811) a vótáil', '(1750–1811) á vótáil'),
#  ('bonn a bhaint', 'bonn á bhaint'),
#  ('daoine a bhíonn', 'daoine á bhíonn'),
#  ('céanna a shaothrú', 'céanna á shaothrú'),
#  ('hiarratas a dhéanamh', 'hiarratas á dhéanamh'),
#  ('dtriallaim a bheith', 'dtriallaim á bheith'),
#  ('fíorsheanda a bhí', 'fíorsheanda á bhí'),
#  ('tús a chur', 'tús á chur'),
#  ('amháin a thuairiscítear', 'amháin á thuairiscítear'),
#  ('é a bunaíodh', 'é á bunaíodh'),
#  ('ealaíne a chruthú', 'ealaíne á chruthú'),
#  ('éarlais a ghearradh\n', 'éarlais á ghearradh\n'),
#  ('chloig a bhíos', 'chloig á bhíos'),
#  ('tacaíocht a thabhairt', 'tacaíocht á thabhairt'),
#  ('Dúiche a bheith', 'Dúiche á bheith'),
#  ('té a bhí', 'té á bhí'),
#  ("d'iarratas a chomhlánú\n", "d'iarratas á chomhlánú\n"),
#  ('eolais a fháil', 'eolais á fháil'),
#  ('suirbhé a dhéanamh', 'suirbhé á dhéanamh'),
#  ('ócáid a bhí', 'ócáid á bhí'),
#  ('Daoine a éalóidh', 'Daoine á éalóidh'),
#  ('mar a thuigim', 'mar á thuigim'),
#  ('nua a chur', 'nua á chur'),
#  ('próisis a shainmhíníonn', 'próisis á shainmhíníonn'),
#  ('páiste a dteastódh', 'páiste á dteastódh'),
#  ('(comharchumann) a úsáid', '(comharchumann) á úsáid'),
#  ('Bháin a cheannach', 'Bháin á cheannach'),
#  ('cumhrán a fháil', 'cumhrán á fháil'),
#  ('deontas a fhaigheann', 'deontas á fhaigheann'),
#  ('sin a bheith', 'sin á bheith'),
#  ('cách a mholadh', 'cách á mholadh'),
#  ('Agus a fheabhas', 'Agus á fheabhas'),
#  ('cíos a shocrú', 'cíos á shocrú'),
#  ('siad a mo', 'siad á mo'),
#  ('DCL a chur', 'DCL á chur'),
#  ('dóigh a féidir', 'dóigh á féidir'),
#  ('Nuair a dhéantar', 'Nuair á dhéantar'),
#  ('té a mheasann', 'té á mheasann'),
#  ('áibhéal a rá', 'áibhéal á rá'),
#  ('stócaireacht a dhéanamh', 'stócaireacht á dhéanamh'),
#  ('Lá a bháis', 'Lá á bháis'),
#  ('ullmhúcháin a bhí', 'ullmhúcháin á bhí'),
#  ('níl a fhios', 'níl á fhios'),
#  ('ar a bhfuil', 'ar á bhfuil'),
#  ('sé a shámhnas', 'sé á shámhnas'),
#  ('ar a laghad', 'ar á laghad'),
#  ('t-uasmhéid a bheidh', 't-uasmhéid á bheidh'),
#  ('muinín a fheabhsú', 'muinín á fheabhsú'),
#  ('chaoi a léirítear', 'chaoi á léirítear'),
#  ('as a chóngaracht', 'as á chóngaracht'),
#  ('maoiniú a bhronnadh', 'maoiniú á bhronnadh'),
#  ('teanga a thréigean', 'teanga á thréigean'),
#  ('daoine a fhreagraíonn', 'daoine á fhreagraíonn'),
#  ('bhfear a fuair', 'bhfear á fuair'),
#  ('Chonamara a deir', 'Chonamara á deir'),
#  ('Ghaeltacht a léirítear', 'Ghaeltacht á léirítear'),
#  ('scéim a ullmhú', 'scéim á ullmhú'),
#  ('tionchar a bhíonn', 'tionchar á bhíonn'),
#  ('iad a híoslódáil', 'iad á híoslódáil'),
#  ('cinneadh a rinneadh', 'cinneadh á rinneadh'),
#  ('aghaidh a thabhairt', 'aghaidh á thabhairt'),
#  ('idirnásiúnta a reáchtáil', 'idirnásiúnta á reáchtáil'),
#  ('fáth a mealleann', 'fáth á mealleann'),
#  ('sé a gcuid', 'sé á gcuid'),
#  ('úll a chur', 'úll á chur'),
#  ('read’ a deir', 'read’ á deir'),
#  ('aghaidh a thabhairt', 'aghaidh á thabhairt'),
#  ('cuairt a thabhairt', 'cuairt á thabhairt'),
#  ('tá a lán', 'tá á lán'),
#  ('sin a spreag', 'sin á spreag'),
#  ('chomhlánaithe a chur', 'chomhlánaithe á chur'),
#  ('anocht a chroí', 'anocht á chroí'),
#  ('bóthar a bhí', 'bóthar á bhí'),
#  ('cruithneacht a cheannach', 'cruithneacht á cheannach'),
#  ('Ghlacadh a athair', 'Ghlacadh á athair'),
#  ('Iarchéime a bhaint', 'Iarchéime á bhaint'),
#  ('coinníollacha a chomhlíonadh', 'coinníollacha á chomhlíonadh'),
#  ("aerfort' a dúirt", "aerfort' á dúirt"),
#  ('duine a dhéanfaidh', 'duine á dhéanfaidh'),
#  ('fad a fhaigheann', 'fad á fhaigheann'),
#  ('idirdhealú a dhéanamh', 'idirdhealú á dhéanamh'),
#  ('FSS a dícheall', 'FSS á dícheall'),
#  ('ag a bhfuil', 'ag á bhfuil'),
#  ('teagmhála a thugann', 'teagmhála á thugann'),
#  ('poiblí a heagríodh', 'poiblí á heagríodh'),
#  ('ar a laghad', 'ar á laghad'),
#  ('toilteanacha a bheith', 'toilteanacha á bheith'),
#  ('cad a tharlóidh', 'cad á tharlóidh'),
#  ('ndaoine a mhaireann', 'ndaoine á mhaireann'),
#  ('an-chiúin a bhí', 'an-chiúin á bhí'),
#  ('chuige a bhí', 'chuige á bhí'),
#  ('ar ais nó', 'ar áis nó'),
#  ('an ais seo', 'an áis seo'),
#  ('mar ais loingseoireachta\n', 'mar áis loingseoireachta\n'),
#  ('Ar ais arís', 'Ar áis arís'),
#  ('ar ais chugam', 'ar áis chugam'),
#  ('ar ais chun', 'ar áis chun'),
#  ('ar ais chun', 'ar áis chun'),
#  ('ar ais don', 'ar áis don'),
#  ('ar ais roimh', 'ar áis roimh'),
#  ('ar ais arís', 'ar áis arís'),
#  ('ar ais ón', 'ar áis ón'),
#  ('ar ais chuige', 'ar áis chuige'),
#  ('ar ais go', 'ar áis go'),
#  ('ar ais arís\n', 'ar áis arís\n'),
#  ('ar ais chun', 'ar áis chun'),
#  ('ar ais –', 'ar áis –'),
#  ('ar ais amháin\n', 'ar áis amháin\n'),
#  ('ar ais ar', 'ar áis ar'),
#  ('ar ais i', 'ar áis i'),
#  ('ar ais @opwcastletown', 'ar áis @opwcastletown'),
#  ('ar ais di', 'ar áis di'),
#  ('ar ais ar', 'ar áis ar'),
#  ('ar ais go', 'ar áis go'),
#  ('ar ais chun', 'ar áis chun'),
#  ('ar ais chuig', 'ar áis chuig'),
#  ('ar ais sa', 'ar áis sa'),
#  ('ar ais go', 'ar áis go'),
#  ('ar ais anois', 'ar áis anois'),
#  ('ar ais \n', 'ar áis \n'),
#  ('ar ais nó', 'ar áis nó'),
#  ('ar ais chuig', 'ar áis chuig'),
#  ('ar ais ar', 'ar áis ar'),
#  ('ar ais na', 'ar áis na'),
#  ('mar ais eolais', 'mar áis eolais'),
#  ('ar ais go', 'ar áis go'),
#  ('- ais íontach', '- áis íontach'),
#  ('ar ais ach', 'ar áis ach'),
#  ('ar ais ina', 'ar áis ina'),
#  ('ar ais isteach', 'ar áis isteach'),
#  ('an ais phleanála', 'an áis phleanála'),
#  ('ar ais linn', 'ar áis linn'),
#  ('[Ar ais chuig', '[Ar áis chuig'),
#  ('ar ais go', 'ar áis go'),
#  ('ar ais i', 'ar áis i'),
#  ('3 ais chúram', '3 áis chúram'),
#  ('ar ais go', 'ar áis go'),
#  ('ar ais go', 'ar áis go'),
#  ('an ais ar-líne', 'an áis ar-líne'),
#  ('[Ar ais chuig', '[Ar áis chuig'),
#  ('ar ais agus', 'ar áis agus'),
#  ('ar ais chun', 'ar áis chun'),
#  ('ar ais chuig', 'ar áis chuig'),
#  ('ar ais san', 'ar áis san'),
#  ('ar ais leis', 'ar áis leis'),
#  ('ar ais go', 'ar áis go'),
#  ('ar ais déanann', 'ar áis déanann'),
#  ('ar ais agus', 'ar áis agus'),
#  ('ar ais don', 'ar áis don'),
#  ('ar ais \n', 'ar áis \n'),
#  ('ar ais ón', 'ar áis ón'),
#  ('ar ais freisin\n', 'ar áis freisin\n'),
#  ('lem ais agus', 'lem áis agus'),
#  ('ar ais libh', 'ar áis libh'),
#  ('ar ais chun', 'ar áis chun'),
#  ('ar ais gan', 'ar áis gan'),
#  ('ar ais chuig', 'ar áis chuig'),
#  ('ar ais é', 'ar áis é'),
#  ('in ais molta', 'in áis molta'),
#  ('ar ais ag', 'ar áis ag'),
#  ('ar ais a', 'ar áis a'),
#  ('ar ais sa', 'ar áis sa'),
#  ('ar ais i', 'ar áis i'),
#  ('ar ais go', 'ar áis go'),
#  ('ar ais roimh', 'ar áis roimh'),
#  ('ar ais mar', 'ar áis mar'),
#  ('ar ais ar', 'ar áis ar'),
#  ('siad ais chúpla', 'siad áis chúpla'),
#  ('ar ais chuig', 'ar áis chuig'),
#  ('ar ais ina', 'ar áis ina'),
#  ('ar ais é', 'ar áis é'),
#  ('ar ais go', 'ar áis go'),
#  ('graf ais 1/u', 'graf áis 1/u'),
#  ('ar ais ar', 'ar áis ar'),
#  ('ar ais arís', 'ar áis arís'),
#  ('ar ais chreidmheasa', 'ar áis chreidmheasa'),
#  ('ar ais agus', 'ar áis agus'),
#  ('níl ais is', 'níl áis is'),
#  ('ar ais chugainn', 'ar áis chugainn'),
#  ('Ar ais go', 'Ar áis go'),
#  ('Gaeilge ais ar-líne', 'Gaeilge áis ar-líne'),
#  ('ar ais an', 'ar áis an'),
#  ('ar ais le', 'ar áis le'),
#  ('ar ais le', 'ar áis le'),
#  ('ar ais ar', 'ar áis ar'),
#  ('ar ais leat', 'ar áis leat'),
#  ('ar ais chuig', 'ar áis chuig'),
#  ('ar ais ar', 'ar áis ar'),
#  ('ar ais go', 'ar áis go'),
#  ('ar ais leis', 'ar áis leis'),
#  ('ar ais nó', 'ar áis nó'),
#  ('ar ais abhaile', 'ar áis abhaile'),
#  ('ar ais chuig', 'ar áis chuig'),
#  ('ar ais go', 'ar áis go'),
#  ('ar ais ar', 'ar áis ar'),
#  ('ar ais go', 'ar áis go'),
#  ('ar ais ar', 'ar áis ar'),
#  ('ar ais \n', 'ar áis \n'),
#  ('Obair/ar ais chun', 'Obair/ar áis chun'),
#  ('ar ais chun', 'ar áis chun'),
#  ('ar ais sa', 'ar áis sa'),
#  ('ar ais chuig', 'ar áis chuig'),
#  ('a ais san', 'a áis san'),
#  ('ar ais arís', 'ar áis arís'),
#  ('ar ais dúinn', 'ar áis dúinn'),
#  ('ar ais agus', 'ar áis agus'),
#  ('ar ais í', 'ar áis í'),
#  ('ar ais chugam', 'ar áis chugam'),
#  ('ar ais go', 'ar áis go'),
#  ('ar ais arís!\n', 'ar áis arís!\n'),
#  ('ar ais isteach;', 'ar áis isteach;'),
#  ('ar ais dó', 'ar áis dó'),
#  ('Cuireadh ais nua', 'Cuireadh áis nua'),
#  ('lena ais dá', 'lena áis dá'),
#  ('mar ais thagartha', 'mar áis thagartha'),
#  ('ar ais go', 'ar áis go'),
#  ('ar ais dó', 'ar áis dó'),
#  ('ar ais go', 'ar áis go'),
#  ('don ais Líonadh', 'don áis Líonadh'),
#  ('ar ais ', 'ar áis '),
#  ('ar ais chuig', 'ar áis chuig'),
#  ('ar ais ina', 'ar áis ina'),
#  ('ar ais in', 'ar áis in'),
#  ('ar ais go', 'ar áis go'),
#  ('ar ais arís', 'ar áis arís'),
#  ('ar ais nuair', 'ar áis nuair'),
#  ('ar ais sa', 'ar áis sa'),
#  ('ar ais chuig', 'ar áis chuig'),
#  ('ar ais chuig', 'ar áis chuig'),
#  ('ar ais ó', 'ar áis ó'),
#  ('ar ais thar', 'ar áis thar'),
#  ('ar ais arís', 'ar áis arís'),
#  ('ar ais in', 'ar áis in'),
#  ('ar ais laethanta', 'ar áis laethanta'),
#  ('ar ais i', 'ar áis i'),
#  ('an ais seo', 'an áis seo'),
#  ('dhá ais ingearacha', 'dhá áis ingearacha'),
#  ('ar ais chuig', 'ar áis chuig'),
#  ('Is ais fhiúntach', 'Is áis fhiúntach'),
#  ('ar ais go', 'ar áis go'),
#  ('ar ais chuig', 'ar áis chuig'),
#  ('ar ais siar', 'ar áis siar'),
#  ('ar ais ar', 'ar áis ar'),
#  ('ar ais amárach…lón', 'ar áis amárach…lón'),
#  ('ar ais a', 'ar áis a'),
#  ('ar ais ar', 'ar áis ar'),
#  ('d ais sábhála\n', 'd áis sábhála\n'),
#  ('ar ais di', 'ar áis di'),
#  ('ar ais go', 'ar áis go'),
#  ('ar ais léi', 'ar áis léi'),
#  ('ar ais ón', 'ar áis ón'),
#  ('ar ais chuig', 'ar áis chuig'),
#  ('ar ais do', 'ar áis do'),
#  ('ar ais an', 'ar áis an'),
#  ('ar ais ag', 'ar áis ag'),
#  ('ar ais sa', 'ar áis sa'),
#  ('Ar ais linn', 'Ar áis linn'),
#  ('ar ais uathu\n', 'ar áis uathu\n'),
#  ('ar ais don', 'ar áis don'),
#  ('ar ais sa', 'ar áis sa'),
#  ('ar ais le', 'ar áis le'),
#  ('ar ais in', 'ar áis in'),
#  ('[Ar ais chuig', '[Ar áis chuig'),
#  ('ar ais go', 'ar áis go'),
#  ('ar ais chuig', 'ar áis chuig'),
#  ('ar ais chuig', 'ar áis chuig'),
#  ('ar ais mar', 'ar áis mar'),
#  ('ar ais ar', 'ar áis ar'),
#  ('ar ais ach', 'ar áis ach'),
#  ('ar ais agamsa', 'ar áis agamsa'),
#  ('ar ais ar', 'ar áis ar'),
#  ('ar ais liom', 'ar áis liom'),
#  ('ar ais go', 'ar áis go'),
#  ('ar ais ón', 'ar áis ón'),
#  ('ar ais chuige', 'ar áis chuige'),
#  ('ar ais ar', 'ar áis ar'),
#  ('ríomhaireachta ais den', 'ríomhaireachta áis den'),
#  ("ar ais dóibh'\n", "ar áis dóibh'\n"),
#  ('a ais ó', 'a áis ó'),
#  ('ar ais anseo\n', 'ar áis anseo\n'),
#  ('ina ais iontach', 'ina áis iontach'),
#  ('ar ais sa', 'ar áis sa'),
#  ('ar ais ar', 'ar áis ar'),
#  ('Ar ais go', 'Ar áis go'),
#  ('ar ais chuig', 'ar áis chuig'),
#  ('ar ais chuig', 'ar áis chuig'),
#  ('ar ais libh', 'ar áis libh'),
#  ('ar ais an', 'ar áis an'),
#  ('ar ais go', 'ar áis go'),
#  ('ar ais ar', 'ar áis ar'),
#  ('ar ais an', 'ar áis an'),
#  ...]

# %%
def basic_probability(option_1,option_2,model):
    if option_1 in model:
        count_1 = model[option_1]
    else:
        count_1 = 0
        
    if option_2 in model:
        count_2 = model[option_2]
    else:
        count_2 = 0
        
    #if count_1 < 4 and count_2 < 4:
    if count_1 == 0 and count_2 == 0:
        split_1 = option_1.split()
        split_2 = option_2.split()
        if len(split_1) > 1 and len(split_2) > 1:
            if len(split_1) % 2 ==0:
                split_1.pop(0)
                split_2.pop(0)
            else:
                split_1.pop()
                split_2.pop()
            new_option_1 = " ".join(split_1)
            new_option_2 = " ".join(split_2)
            return basic_probability(new_option_1,new_option_2,model)
            
    elif count_1 == 0:
        count_1 = .1
    elif count_2 == 0:
        count_2 = .1
        
    prob_1 = count_1/(count_1+count_2)
    prob_2 = count_2/(count_1+count_2)
    return prob_1, prob_2

# %%
start = time.time()
prob = basic_probability(choices[0][0],choices[0][1],model)
end = time.time()
print(end-start, prob)
# Out:
# 8.988380432128906e-05 (0.9937888198757763, 0.006211180124223602)

# %%
expected_runtime = (end-start)*20000
expected_runtime/60
# Out:
# 0.029961268107096355

# %% [markdown]
# ### Try Bigram Model

# %%
def evaluate_model(model, choices):
    results = [['Id','Expected']]
    for index, choice in enumerate(choices):
        c1,c2 = basic_probability(choice[0],choice[1],model)
        results.append([index+1,c1])
    return results

# %%
results = evaluate_model(model,choices)

# %%
results
# Out:
# [['Id', 'Expected'],
#  [1, 0.9937888198757763],
#  [2, 0.9090909090909091],
#  [3, 0.9090909090909091],
#  [4, 0.9428571428571428],
#  [5, 0.9552238805970149],
#  [6, 0.9995497523638002],
#  [7, 0.9090909090909091],
#  [8, 0.9958506224066389],
#  [9, 0.989010989010989],
#  [10, 0.9090909090909091],
#  [11, 0.9838709677419355],
#  [12, 0.9667087094513829],
#  [13, 0.9090909090909091],
#  [14, 0.9667087094513829],
#  [15, 0.9888888888888889],
#  [16, 0.9999549772635181],
#  [17, 0.9756097560975611],
#  [18, 0.05063291139240506],
#  [19, 0.9667087094513829],
#  [20, 0.9941520467836257],
#  [21, 0.9803921568627452],
#  [22, 0.9803921568627452],
#  [23, 0.9677419354838709],
#  [24, 0.999674373168349],
#  [25, 0.9923664122137404],
#  [26, 0.4444444444444444],
#  [27, 0.9768518518518519],
#  [28, 0.9677419354838709],
#  [29, 0.9090909090909091],
#  [30, 0.9941520467836257],
#  [31, 0.9999549772635181],
#  [32, 0.9032258064516129],
#  [33, 0.9523809523809523],
#  [34, 0.9973753280839894],
#  [35, 0.9923664122137404],
#  [36, 0.9837133550488599],
#  [37, 0.9992372234935164],
#  [38, 0.9993425378040763],
#  [39, 0.6666666666666666],
#  [40, 0.9929078014184397],
#  [41, 0.9987808594940567],
#  [42, 0.9994874423372629],
#  [43, 0.990990990990991],
#  [44, 0.9677419354838709],
#  [45, 0.9859154929577465],
#  [46, 0.9995240361732508],
#  [47, 0.9917355371900827],
#  [48, 0.999607996863975],
#  [49, 0.9090909090909091],
#  [50, 0.9958506224066389],
#  [51, 0.8666666666666667],
#  [52, 0.9777777777777777],
#  [53, 0.9177869700103413],
#  [54, 0.9488243430152143],
#  [55, 0.9999549772635181],
#  [56, 0.9950248756218905],
#  [57, 0.96],
#  [58, 0.9999500773800609],
#  [59, 0.9796359148410985],
#  [60, 0.9816053511705686],
#  [61, 0.9090909090909091],
#  [62, 0.9090909090909091],
#  [63, 0.9876543209876544],
#  [64, 0.9090909090909091],
#  [65, 0.09090909090909091],
#  [66, 0.9985734664764623],
#  [67, 0.9615384615384616],
#  [68, 0.9523809523809523],
#  [69, 0.6666666666666666],
#  [70, 0.9965635738831614],
#  [71, 0.9821428571428571],
#  [72, 0.9677419354838709],
#  [73, 0.9876543209876544],
#  [74, 0.9523809523809523],
#  [75, 0.9667087094513829],
#  [76, 0.9815950920245399],
#  [77, 0.9644808743169399],
#  [78, 0.9298136645962732],
#  [79, 0.9090909090909091],
#  [80, 0.9998585772875124],
#  [81, 0.9177869700103413],
#  [82, 0.9677419354838709],
#  [83, 0.9359823399558499],
#  [84, 0.9910714285714286],
#  [85, 0.9836065573770493],
#  [86, 0.9967845659163986],
#  [87, 0.9166666666666666],
#  [88, 0.9947643979057591],
#  [89, 0.9977324263038548],
#  [90, 0.9090909090909091],
#  [91, 0.9971509971509971],
#  [92, 0.957983193277311],
#  [93, 0.9998084658111472],
#  [94, 0.9992862241256246],
#  [95, 0.9108910891089109],
#  [96, 0.9983361064891847],
#  [97, 0.9667087094513829],
#  [98, 0.9999796213649609],
#  [99, 0.9667087094513829],
#  [100, 0.9523809523809523],
#  [101, 0.9996199163816039],
#  [102, 0.9994767137624281],
#  [103, 0.9667087094513829],
#  [104, 0.9997110661658479],
#  [105, 0.9803921568627452],
#  [106, 0.9090909090909091],
#  [107, 0.9978308026030368],
#  [108, 0.9803921568627452],
#  [109, 0.9933774834437087],
#  [110, 0.9996017522899243],
#  [111, 0.9989594172736733],
#  [112, 0.9090909090909091],
#  [113, 0.9090909090909091],
#  [114, 0.9090909090909091],
#  [115, 0.9940119760479041],
#  [116, 0.9814746202297147],
#  [117, 0.9555555555555556],
#  [118, 0.9982788296041308],
#  [119, 0.9667087094513829],
#  [120, 0.9659090909090909],
#  [121, 0.9667087094513829],
#  [122, 0.9803921568627452],
#  [123, 0.8],
#  [124, 0.9090909090909091],
#  [125, 0.9999902497050536],
#  [126, 0.990990990990991],
#  [127, 0.998766954377312],
#  [128, 0.9876543209876544],
#  [129, 0.8125],
#  [130, 0.9803921568627451],
#  [131, 0.9620253164556962],
#  [132, 0.0025575447570332483],
#  [133, 0.9090909090909091],
#  [134, 0.9992193598750976],
#  [135, 0.990990990990991],
#  [136, 0.9756097560975611],
#  [137, 0.9411764705882353],
#  [138, 0.9995596653456628],
#  [139, 0.9877300613496932],
#  [140, 0.989010989010989],
#  [141, 0.9756097560975611],
#  [142, 0.9973045822102425],
#  [143, 0.989010989010989],
#  [144, 0.9667087094513829],
#  [145, 0.9523809523809523],
#  [146, 0.998389694041868],
#  [147, 0.9991532599491957],
#  [148, 0.9523809523809523],
#  [149, 0.9667087094513829],
#  [150, 0.9991532599491957],
#  [151, 0.9956709956709956],
#  [152, 0.9988518943742825],
#  [153, 0.9473684210526315],
#  [154, 0.9677419354838709],
#  [155, 0.9972299168975068],
#  [156, 0.9803921568627452],
#  [157, 0.9996875976257419],
#  [158, 0.9667087094513829],
#  [159, 0.9090909090909091],
#  [160, 0.9090909090909091],
#  [161, 0.9090909090909091],
#  [162, 0.9667087094513829],
#  [163, 0.8635907723169508],
#  [164, 0.9929078014184397],
#  [165, 0.9987029831387809],
#  [166, 0.9900990099009901],
#  [167, 0.999530736743313],
#  [168, 0.9677419354838709],
#  [169, 0.9933774834437087],
#  [170, 0.9907932011331445],
#  [171, 0.999768572089794],
#  [172, 0.9667087094513829],
#  [173, 0.9917355371900827],
#  [174, 0.9677419354838709],
#  [175, 0.9941520467836257],
#  [176, 0.9787234042553191],
#  [177, 0.9523809523809523],
#  [178, 0.9090909090909091],
#  [179, 0.9923664122137404],
#  [180, 0.9969788519637461],
#  [181, 0.9923664122137404],
#  [182, 0.9090909090909091],
#  [183, 0.9902912621359223],
#  [184, 0.9562841530054644],
#  [185, 0.9166666666666666],
#  [186, 0.9756097560975611],
#  [187, 0.990990990990991],
#  [188, 0.9090909090909091],
#  [189, 0.9090909090909091],
#  [190, 0.9958506224066389],
#  [191, 0.9793103448275862],
#  [192, 0.9971509971509971],
#  [193, 0.9482758620689655],
#  [194, 0.974025974025974],
#  [195, 0.9859154929577465],
#  [196, 0.9090909090909091],
#  [197, 0.9956709956709956],
#  [198, 0.9667087094513829],
#  [199, 0.9995517705064993],
#  [200, 0.9900990099009901],
#  [201, 0.9667087094513829],
#  [202, 0.9615384615384616],
#  [203, 0.9803921568627452],
#  [204, 0.9866666666666667],
#  [205, 0.921161825726141],
#  [206, 0.9950248756218905],
#  [207, 0.9667087094513829],
#  [208, 0.9756097560975611],
#  [209, 0.9992372234935164],
#  [210, 0.9879659524508365],
#  [211, 0.9956709956709956],
#  [212, 0.9911504424778761],
#  [213, 0.9090909090909091],
#  [214, 0.8888888888888888],
#  [215, 0.9667087094513829],
#  [216, 0.998389694041868],
#  [217, 0.9876543209876544],
#  [218, 0.9074626865671642],
#  [219, 0.9958506224066389],
#  [220, 0.9677419354838709],
#  [221, 0.9947643979057591],
#  [222, 0.9090909090909091],
#  [223, 0.997624703087886],
#  [224, 0.9411764705882353],
#  [225, 0.9696969696969697],
#  [226, 0.9992542878448919],
#  [227, 0.9793275217932752],
#  [228, 0.9523809523809523],
#  [229, 0.9803921568627452],
#  [230, 0.989010989010989],
#  [231, 0.9],
#  [232, 0.9667087094513829],
#  [233, 0.9677419354838709],
#  [234, 0.9523809523809523],
#  [235, 0.9776286353467561],
#  [236, 0.9988518943742825],
#  [237, 0.9997268505872712],
#  [238, 0.9667087094513829],
#  [239, 0.9677419354838709],
#  [240, 0.9933774834437087],
#  [241, 0.9090909090909091],
#  [242, 0.9625668449197861],
#  [243, 0.9830508474576272],
#  [244, 0.9523809523809523],
#  [245, 0.971830985915493],
#  [246, 0.9941520467836257],
#  [247, 0.9677419354838709],
#  [248, 0.9999500773800609],
#  [249, 0.9917355371900827],
#  [250, 0.9702517162471396],
#  [251, 0.9428571428571428],
#  [252, 0.9978768577494692],
#  [253, 0.9929078014184397],
#  [254, 0.9859154929577465],
#  [255, 0.9090909090909091],
#  [256, 0.9992069785884219],
#  [257, 0.9677419354838709],
#  [258, 0.9523809523809523],
#  [259, 0.9166666666666666],
#  [260, 0.9973753280839894],
#  [261, 0.998613037447989],
#  [262, 0.9979209979209979],
#  [263, 0.975],
#  [264, 0.9793103448275862],
#  [265, 0.9929078014184397],
#  [266, 0.9999143908911909],
#  [267, 0.9987966305655837],
#  [268, 0.9667087094513829],
#  [269, 0.9836065573770493],
#  [270, 0.9944751381215469],
#  [271, 0.975609756097561],
#  [272, 0.9523809523809523],
#  [273, 0.9967845659163986],
#  [274, 0.9836065573770493],
#  [275, 0.9090909090909091],
#  [276, 0.9644808743169399],
#  [277, 0.989010989010989],
#  [278, 0.9523809523809523],
#  [279, 0.9523809523809523],
#  [280, 0.9948979591836735],
#  [281, 0.999666777740753],
#  [282, 0.9566968781470292],
#  [283, 0.9985528219971057],
#  [284, 0.9710381987876455],
#  [285, 0.9964412811387899],
#  [286, 0.9090909090909091],
#  [287, 0.75],
#  [288, 0.9318181818181818],
#  [289, 0.9677419354838709],
#  [290, 0.9806312769010043],
#  [291, 0.9667087094513829],
#  [292, 0.9859154929577465],
#  [293, 0.9512195121951219],
#  [294, 0.9876543209876544],
#  [295, 0.8148148148148148],
#  [296, 0.9667087094513829],
#  [297, 0.9090909090909091],
#  [298, 0.9900990099009901],
#  [299, 0.005235602094240838],
#  [300, 0.9667087094513829],
#  [301, 0.9987966305655837],
#  [302, 0.984251968503937],
#  [303, 0.9677419354838709],
#  [304, 0.9230769230769231],
#  [305, 0.9982174688057041],
#  [306, 0.047619047619047616],
#  [307, 0.9884169884169884],
#  [308, 0.9958506224066389],
#  [309, 0.9967845659163986],
#  [310, 0.9993552546744037],
#  [311, 0.9859154929577465],
#  [312, 0.9937888198757763],
#  [313, 0.13152220784821045],
#  [314, 0.9677419354838709],
#  [315, 0.9974424552429667],
#  [316, 0.9983079526226734],
#  [317, 0.9090909090909091],
#  [318, 0.9090909090909091],
#  [319, 0.9985528219971057],
#  [320, 0.9979838709677419],
#  [321, 0.9090909090909091],
#  [322, 0.9196891191709845],
#  [323, 0.9999549772635181],
#  [324, 0.9997429966589565],
#  [325, 0.8],
#  [326, 0.9090909090909091],
#  [327, 0.9859154929577465],
#  [328, 0.9874213836477987],
#  [329, 0.9090909090909091],
#  [330, 0.5],
#  [331, 0.9793275217932752],
#  [332, 0.9983633387888707],
#  [333, 0.9996722386102916],
#  [334, 0.9751121991024072],
#  [335, 0.9776286353467561],
#  [336, 0.989010989010989],
#  [337, 0.9667087094513829],
#  [338, 0.9756097560975611],
#  [339, 0.9900990099009901],
#  [340, 0.9806201550387597],
#  [341, 0.9090909090909091],
#  [342, 0.9820627802690582],
#  [343, 0.9998233527645292],
#  [344, 0.9667087094513829],
#  [345, 0.9756097560975611],
#  [346, 0.9677419354838709],
#  [347, 0.49583066067992304],
#  [348, 0.9335585585585585],
#  [349, 0.9667087094513829],
#  [350, 0.9285714285714286],
#  [351, 0.75],
#  [352, 0.9552238805970149],
#  [353, 0.9996467679265276],
#  [354, 0.9998595702850723],
#  [355, 0.9803921568627452],
#  [356, 0.9523809523809523],
#  [357, 0.96],
#  [358, 0.990990990990991],
#  [359, 0.9090909090909091],
#  [360, 0.9803921568627452],
#  [361, 0.9803921568627452],
#  [362, 0.9523809523809523],
#  [363, 0.9997355546740712],
#  [364, 0.9],
#  [365, 0.9907407407407407],
#  [366, 0.9989484752891693],
#  [367, 0.9996467679265276],
#  [368, 0.990909090909091],
#  [369, 0.9667087094513829],
#  [370, 0.9803921568627452],
#  [371, 0.998003992015968],
#  [372, 0.9677419354838709],
#  [373, 0.9950248756218905],
#  [374, 0.9649122807017544],
#  [375, 0.9667087094513829],
#  [376, 0.9994447529150472],
#  [377, 0.9],
#  [378, 0.9677419354838709],
#  [379, 0.9999549772635181],
#  [380, 0.9809316920106204],
#  [381, 0.9677419354838709],
#  [382, 0.9974424552429667],
#  [383, 0.9946808510638298],
#  [384, 0.9976798143851507],
#  [385, 0.9803921568627452],
#  [386, 0.9090909090909091],
#  [387, 0.9523809523809523],
#  [388, 0.9756097560975611],
#  [389, 0.9090909090909091],
#  [390, 0.9744897959183674],
#  [391, 0.9667087094513829],
#  [392, 0.9917355371900827],
#  [393, 0.9090909090909091],
#  [394, 0.9523809523809523],
#  [395, 0.9803921568627452],
#  [396, 0.9523809523809523],
#  [397, 0.9677419354838709],
#  [398, 0.9966777408637874],
#  [399, 0.998003992015968],
#  [400, 0.99985121261717],
#  [401, 0.995260663507109],
#  [402, 0.9523809523809523],
#  [403, 0.989010989010989],
#  [404, 0.9982174688057041],
#  [405, 0.9980430528375733],
#  [406, 0.8854961832061069],
#  [407, 0.990990990990991],
#  [408, 0.9988109393579073],
#  [409, 0.9859154929577465],
#  [410, 0.9523809523809523],
#  [411, 0.9836065573770493],
#  [412, 0.9677419354838709],
#  [413, 0.9090909090909091],
#  [414, 0.9863013698630136],
#  [415, 0.9752066115702479],
#  [416, 0.9803921568627452],
#  [417, 0.9989934574735783],
#  [418, 0.9998938541556098],
#  [419, 0.9361702127659575],
#  [420, 0.8852459016393442],
#  [421, 0.9971509971509971],
#  [422, 0.993103448275862],
#  [423, 0.9935064935064936],
#  [424, 0.9992193598750976],
#  [425, 0.9552238805970149],
#  [426, 0.9090909090909091],
#  [427, 0.9859154929577465],
#  [428, 0.9677419354838709],
#  [429, 0.9756097560975611],
#  [430, 0.9667087094513829],
#  [431, 0.9667087094513829],
#  [432, 0.9976798143851507],
#  [433, 0.9923664122137404],
#  [434, 0.9814814814814815],
#  [435, 0.9999549772635181],
#  [436, 0.99601593625498],
#  [437, 0.9196891191709845],
#  [438, 0.9969788519637461],
#  [439, 0.9941520467836257],
#  [440, 0.9803921568627452],
#  [441, 0.9976798143851507],
#  [442, 0.9793275217932752],
#  [443, 0.9974424552429667],
#  [444, 0.9992006394884093],
#  [445, 0.9090909090909091],
#  [446, 0.9090909090909091],
#  [447, 0.875],
#  [448, 0.9983361064891847],
#  [449, 0.9677419354838709],
#  [450, 0.9992254066615027],
#  [451, 0.9615384615384616],
#  [452, 0.9090909090909091],
#  [453, 0.9552238805970149],
#  [454, 0.9991158267020337],
#  [455, 0.9998938541556098],
#  [456, 0.9090909090909091],
#  [457, 0.9933774834437087],
#  [458, 0.9999500773800609],
#  [459, 0.9090909090909091],
#  [460, 0.9090909090909091],
#  [461, 0.9677419354838709],
#  [462, 0.9090909090909091],
#  [463, 0.9987195902688861],
#  [464, 0.9955290611028316],
#  [465, 0.9667087094513829],
#  [466, 0.9991785483776331],
#  [467, 0.9999796213649609],
#  [468, 0.9968847352024922],
#  [469, 0.9852941176470589],
#  [470, 0.9960159362549801],
#  [471, 0.9803921568627452],
#  [472, 0.999057492931197],
#  [473, 0.9523809523809523],
#  [474, 0.8849206349206349],
#  [475, 0.9090909090909091],
#  [476, 0.9523809523809523],
#  [477, 0.9090909090909091],
#  [478, 0.9090909090909091],
#  [479, 0.9756097560975611],
#  [480, 0.9947643979057591],
#  [481, 0.9984871406959154],
#  [482, 0.9979633401221996],
#  [483, 0.9090909090909091],
#  [484, 0.9998680912808336],
#  [485, 0.999315537303217],
#  [486, 0.9523809523809523],
#  [487, 0.9523809523809523],
#  [488, 0.9667087094513829],
#  [489, 0.8],
#  [490, 0.9803921568627452],
#  [491, 0.9981515711645101],
#  [492, 0.9677419354838709],
#  [493, 0.9523809523809523],
#  [494, 0.9090909090909091],
#  [495, 0.9090909090909091],
#  [496, 0.9987357774968395],
#  [497, 0.9836065573770493],
#  [498, 0.9997389715478987],
#  [499, 0.9985935302390999],
#  [500, 0.9991785483776331],
#  [501, 0.9984871406959154],
#  [502, 0.9090909090909091],
#  [503, 0.3076923076923077],
#  [504, 0.9803921568627452],
#  [505, 0.9988518943742825],
#  [506, 0.9090909090909091],
#  [507, 0.9973753280839894],
#  [508, 0.9977324263038548],
#  [509, 0.9988776655443323],
#  [510, 0.9354838709677419],
#  [511, 0.9803921568627452],
#  [512, 0.997506234413965],
#  [513, 0.9523809523809523],
#  [514, 0.9958506224066389],
#  [515, 0.9090909090909091],
#  [516, 0.9965635738831614],
#  [517, 0.9090909090909091],
#  [518, 0.9677419354838709],
#  [519, 0.9876543209876544],
#  [520, 0.9090909090909091],
#  [521, 0.9963099630996309],
#  [522, 0.9642857142857143],
#  [523, 0.9361702127659575],
#  [524, 0.9090909090909091],
#  [525, 0.9900990099009901],
#  [526, 0.9583333333333334],
#  [527, 0.9961685823754789],
#  [528, 0.9552238805970149],
#  [529, 0.9523809523809523],
#  [530, 0.8],
#  [531, 0.9836065573770493],
#  [532, 0.9583333333333334],
#  [533, 0.9090909090909091],
#  [534, 0.9756097560975611],
#  [535, 0.9955290611028316],
#  [536, 0.9710381987876455],
#  [537, 0.9012658227848102],
#  [538, 0.9370015948963317],
#  [539, 0.989010989010989],
#  [540, 0.9941520467836257],
#  [541, 0.9915014164305949],
#  [542, 0.8181818181818182],
#  [543, 0.9428571428571428],
#  [544, 0.9677419354838709],
#  [545, 0.9090909090909091],
#  [546, 0.9941520467836257],
#  [547, 0.9414348462664714],
#  [548, 0.9756097560975611],
#  [549, 0.9756097560975611],
#  [550, 0.9948409286328461],
#  [551, 0.01639344262295082],
#  [552, 0.9941520467836257],
#  [553, 0.998766954377312],
#  [554, 0.9999075016187218],
#  [555, 0.9661016949152542],
#  [556, 0.9722222222222222],
#  [557, 0.9090909090909091],
#  [558, 0.9985734664764623],
#  [559, 0.9861111111111112],
#  [560, 0.9740082079343365],
#  [561, 0.9667087094513829],
#  [562, 0.9984152139461172],
#  [563, 0.9978768577494692],
#  [564, 0.9965635738831614],
#  [565, 0.9756097560975611],
#  [566, 0.989010989010989],
#  [567, 0.9711538461538461],
#  [568, 0.9090909090909091],
#  [569, 0.9714285714285714],
#  [570, 0.9667087094513829],
#  [571, 0.9722222222222222],
#  [572, 0.9090909090909091],
#  [573, 0.9756097560975611],
#  [574, 0.9772727272727273],
#  [575, 0.9997826559443599],
#  [576, 0.9667087094513829],
#  [577, 0.9836065573770493],
#  [578, 0.9972299168975068],
#  [579, 0.9941176470588236],
#  [580, 0.99],
#  [581, 0.9821428571428571],
#  [582, 0.9793275217932752],
#  [583, 0.9558225987723696],
#  [584, 0.9740082079343365],
#  [585, 0.9743589743589743],
#  [586, 0.9756097560975611],
#  [587, 0.9130434782608695],
#  [588, 0.96],
#  [589, 0.9992069785884219],
#  [590, 0.9704142011834319],
#  [591, 0.9933774834437087],
#  [592, 0.9793275217932752],
#  [593, 0.9090909090909091],
#  [594, 0.9723502304147466],
#  [595, 0.9654427645788337],
#  [596, 0.9677419354838709],
#  [597, 0.9090909090909091],
#  [598, 0.9970674486803519],
#  [599, 0.9667087094513829],
#  [600, 0.9779411764705882],
#  [601, 0.9876543209876544],
#  [602, 0.9859154929577465],
#  [603, 0.997624703087886],
#  [604, 0.9876543209876544],
#  [605, 0.9667087094513829],
#  [606, 0.999607996863975],
#  [607, 0.9677419354838709],
#  [608, 0.9166666666666666],
#  [609, 0.9677419354838709],
#  [610, 0.9230769230769231],
#  [611, 0.9677419354838709],
#  [612, 0.9713114754098361],
#  [613, 0.9090909090909091],
#  [614, 0.9996213555471412],
#  [615, 0.9974895397489539],
#  [616, 0.999846413761327],
#  [617, 0.9784386617100371],
#  [618, 0.9677419354838709],
#  [619, 0.9677419354838709],
#  [620, 0.9980806142034548],
#  [621, 0.9692307692307692],
#  [622, 0.8854961832061069],
#  [623, 0.8387096774193549],
#  [624, 0.9876543209876544],
#  [625, 0.9677419354838709],
#  [626, 0.9917355371900827],
#  [627, 0.9523809523809523],
#  [628, 0.9090909090909091],
#  [629, 0.9924098671726755],
#  [630, 0.9973579920739762],
#  [631, 0.9937888198757763],
#  [632, 0.9667087094513829],
#  [633, 0.9667087094513829],
#  [634, 0.9523809523809523],
#  [635, 0.998613037447989],
#  [636, 0.9667087094513829],
#  [637, 0.9375],
#  [638, 0.9859154929577465],
#  [639, 0.9972299168975068],
#  [640, 0.9917355371900827],
#  [641, 0.9074626865671642],
#  [642, 0.014084507042253523],
#  [643, 0.9923664122137404],
#  [644, 0.9876543209876544],
#  [645, 0.9944751381215469],
#  [646, 0.9090909090909091],
#  [647, 0.9523809523809523],
#  [648, 0.9994597514856834],
#  [649, 0.9978308026030368],
#  [650, 0.9979838709677419],
#  [651, 0.9516129032258065],
#  [652, 0.9523809523809523],
#  [653, 0.9988385598141697],
#  [654, 0.9991785483776331],
#  [655, 0.989010989010989],
#  [656, 0.5],
#  [657, 0.9998595702850723],
#  [658, 0.9743589743589743],
#  [659, 0.9587628865979382],
#  [660, 0.990990990990991],
#  [661, 0.8762886597938144],
#  [662, 0.9667087094513829],
#  [663, 0.931899641577061],
#  [664, 0.9756097560975611],
#  [665, 0.9012658227848102],
#  [666, 0.9934640522875817],
#  [667, 0.9523809523809523],
#  [668, 0.9995027349577325],
#  [669, 0.9803921568627452],
#  [670, 0.9806312769010043],
#  [671, 0.9961685823754789],
#  [672, 0.9285714285714286],
#  [673, 0.9523809523809523],
#  [674, 0.9583333333333334],
#  [675, 0.9836065573770493],
#  [676, 0.9370015948963317],
#  [677, 0.9677419354838709],
#  [678, 0.9803921568627452],
#  [679, 0.9728813559322034],
#  [680, 0.9380165289256198],
#  [681, 0.8854961832061069],
#  [682, 0.9803921568627452],
#  [683, 0.99],
#  [684, 0.019607843137254905],
#  [685, 0.9667087094513829],
#  [686, 0.9999075016187218],
#  [687, 0.9999500773800609],
#  [688, 0.9090909090909091],
#  [689, 0.9998585772875124],
#  [690, 0.9997743173098623],
#  [691, 0.9970674486803519],
#  [692, 0.9667087094513829],
#  [693, 0.9523809523809523],
#  [694, 0.9876543209876544],
#  [695, 0.9997355546740712],
#  [696, 0.9591121495327103],
#  [697, 0.9941520467836257],
#  [698, 0.984],
#  [699, 0.9090909090909091],
#  [700, 0.9859154929577465],
#  [701, 0.9756097560975611],
#  [702, 0.9859571322985957],
#  [703, 0.9677419354838709],
#  [704, 0.9523809523809523],
#  [705, 0.9026548672566371],
#  [706, 0.9090909090909091],
#  [707, 0.9859154929577465],
#  [708, 0.9667087094513829],
#  [709, 0.9523809523809523],
#  [710, 0.9667087094513829],
#  [711, 0.7857142857142857],
#  [712, 0.9984871406959154],
#  [713, 0.09090909090909091],
#  [714, 0.9967845659163986],
#  [715, 0.9667087094513829],
#  [716, 0.9667087094513829],
#  [717, 0.9012658227848102],
#  [718, 0.9090909090909091],
#  [719, 0.9090909090909091],
#  [720, 0.9090909090909091],
#  [721, 0.9967845659163986],
#  [722, 0.9090909090909091],
#  [723, 0.9948849104859335],
#  [724, 0.9756097560975611],
#  [725, 0.999834190018239],
#  [726, 0.9984399375975039],
#  [727, 0.9997110661658479],
#  [728, 0.989010989010989],
#  [729, 0.989010989010989],
#  [730, 0.9753086419753086],
#  [731, 0.9974424552429667],
#  [732, 0.968609865470852],
#  [733, 0.96],
#  [734, 0.96875],
#  [735, 0.9090909090909091],
#  [736, 0.9836065573770493],
#  [737, 0.9667087094513829],
#  [738, 0.9523809523809523],
#  [739, 0.9998117115420825],
#  [740, 0.9956709956709956],
#  [741, 0.9662921348314607],
#  [742, 0.9495798319327731],
#  [743, 0.8635907723169508],
#  [744, 0.9667087094513829],
#  [745, 0.9979716024340771],
#  [746, 0.9972299168975068],
#  [747, 0.9523809523809523],
#  [748, 0.9667087094513829],
#  [749, 0.9667087094513829],
#  [750, 0.9166666666666666],
#  [751, 0.9803921568627452],
#  [752, 0.999569151227919],
#  [753, 0.9998595702850723],
#  [754, 0.8860142482189727],
#  [755, 0.9999500773800609],
#  [756, 0.9523809523809523],
#  [757, 0.9990834097158571],
#  [758, 0.9998293806517659],
#  [759, 0.9090909090909091],
#  [760, 0.9074074074074074],
#  [761, 0.9414348462664714],
#  [762, 0.9806312769010043],
#  [763, 0.9523809523809523],
#  [764, 0.9090909090909091],
#  [765, 0.9636363636363636],
#  [766, 0.9876543209876544],
#  [767, 0.998003992015968],
#  [768, 0.9809316920106204],
#  [769, 0.9803921568627452],
#  [770, 0.9879518072289156],
#  [771, 0.9667087094513829],
#  [772, 0.9997717416115042],
#  [773, 0.9836065573770493],
#  [774, 0.9836065573770493],
#  [775, 0.9667087094513829],
#  [776, 0.9879518072289156],
#  [777, 0.9979035639412998],
#  [778, 0.9985528219971057],
#  [779, 0.989010989010989],
#  [780, 0.9961685823754789],
#  [781, 0.9974424552429667],
#  [782, 0.9677419354838709],
#  [783, 0.9090909090909091],
#  [784, 0.9090909090909091],
#  [785, 0.9523809523809523],
#  [786, 0.9900990099009901],
#  [787, 0.9667087094513829],
#  [788, 0.9988901220865706],
#  [789, 0.9803921568627452],
#  [790, 0.9897959183673469],
#  [791, 0.9354838709677419],
#  [792, 0.9923809523809524],
#  [793, 0.9090909090909091],
#  [794, 0.9573712255772646],
#  [795, 0.9999500773800609],
#  [796, 0.9667087094513829],
#  [797, 0.9947643979057591],
#  [798, 0.9677419354838709],
#  [799, 0.9667087094513829],
#  [800, 0.9954751131221719],
#  [801, 0.9659863945578231],
#  [802, 0.01762114537444934],
#  [803, 0.0107095046854083],
#  [804, 0.9818181818181818],
#  [805, 0.9937106918238994],
#  [806, 0.9998358233459201],
#  [807, 0.9998358233459201],
#  [808, 0.9977924944812362],
#  [809, 0.9994568169473113],
#  [810, 0.9986244841815681],
#  [811, 0.9939759036144579],
#  [812, 0.9994478188845942],
#  [813, 0.9971850809289233],
#  [814, 0.996240753466187],
#  [815, 0.9998358233459201],
#  [816, 0.9964412811387899],
#  [817, 0.996240753466187],
#  [818, 0.9950666008880118],
#  [819, 0.9992657856093979],
#  [820, 0.996240753466187],
#  [821, 0.9958506224066389],
#  [822, 0.9950666008880118],
#  [823, 0.9971850809289233],
#  [824, 0.9998358233459201],
#  [825, 0.9991129509166173],
#  [826, 0.9998950792151925],
#  [827, 0.9971850809289233],
#  [828, 0.9989484752891693],
#  [829, 0.8826197808019602],
#  [830, 0.9659863945578231],
#  [831, 0.9991129509166173],
#  [832, 0.9950666008880118],
#  [833, 0.987012987012987],
#  [834, 0.014084507042253523],
#  [835, 0.9971850809289233],
#  [836, 0.1],
#  [837, 0.9908256880733946],
#  [838, 0.9995852343425965],
#  [839, 0.9994015559545183],
#  [840, 0.009900990099009901],
#  [841, 0.9885057471264368],
#  [842, 0.999689537410742],
#  [843, 0.9971850809289233],
#  [844, 0.9992657856093979],
#  [845, 0.25],
#  [846, 0.9971850809289233],
#  [847, 0.9971850809289233],
#  [848, 0.03225806451612903],
#  [849, 0.999689537410742],
#  [850, 0.9956521739130435],
#  [851, 0.9998358233459201],
#  [852, 0.9991129509166173],
#  [853, 0.9996351696461144],
#  [854, 0.9995051954477981],
#  [855, 0.9971850809289233],
#  [856, 0.996240753466187],
#  [857, 0.9956521739130435],
#  [858, 0.9977924944812362],
#  [859, 0.8826197808019602],
#  [860, 0.9939759036144579],
#  [861, 0.996240753466187],
#  [862, 0.989010989010989],
#  [863, 0.9259259259259259],
#  [864, 0.9998358233459201],
#  [865, 0.9987357774968395],
#  [866, 0.9991129509166173],
#  [867, 0.9994256174612293],
#  [868, 0.28],
#  [869, 0.9978354978354979],
#  [870, 0.9565217391304348],
#  [871, 0.9998950792151925],
#  [872, 0.9992657856093979],
#  [873, 0.9971850809289233],
#  [874, 0.9994568169473113],
#  [875, 0.983402489626556],
#  [876, 0.9950666008880118],
#  [877, 0.09090909090909091],
#  [878, 0.9991129509166173],
#  [879, 0.9995852343425965],
#  [880, 0.9994256174612293],
#  [881, 0.9971850809289233],
#  [882, 0.8826197808019602],
#  [883, 0.9950666008880118],
#  [884, 0.9986244841815681],
#  [885, 0.996240753466187],
#  [886, 0.9956521739130435],
#  [887, 0.6666666666666666],
#  [888, 0.9931972789115646],
#  [889, 0.9971098265895953],
#  [890, 0.5],
#  [891, 0.9908814589665653],
#  [892, 0.999810641923878],
#  [893, 0.999810641923878],
#  [894, 0.9950666008880118],
#  [895, 0.995260663507109],
#  [896, 0.9991129509166173],
#  [897, 0.9950666008880118],
#  [898, 0.9971850809289233],
#  [899, 0.9995051954477981],
#  [900, 0.9659863945578231],
#  [901, 0.9924812030075187],
#  [902, 0.9991129509166173],
#  [903, 0.9971850809289233],
#  [904, 0.9950666008880118],
#  [905, 0.9971850809289233],
#  [906, 0.9950666008880118],
#  [907, 0.8826197808019602],
#  [908, 0.8826197808019602],
#  [909, 0.9998358233459201],
#  [910, 0.9998950792151925],
#  [911, 0.9991129509166173],
#  [912, 0.8235294117647058],
#  [913, 0.9986244841815681],
#  [914, 0.9947643979057591],
#  [915, 0.9956521739130435],
#  [916, 0.9992193598750976],
#  [917, 0.9937106918238994],
#  [918, 0.9971850809289233],
#  [919, 0.996240753466187],
#  [920, 0.996240753466187],
#  [921, 0.9989909182643795],
#  [922, 0.09090909090909091],
#  [923, 0.9848484848484849],
#  [924, 0.00398406374501992],
#  [925, 0.9971850809289233],
#  [926, 0.9989909182643795],
#  [927, 0.9971850809289233],
#  [928, 0.004524886877828054],
#  [929, 0.8826197808019602],
#  [930, 0.9991129509166173],
#  [931, 0.9995852343425965],
#  [932, 0.9970501474926253],
#  [933, 0.9971850809289233],
#  [934, 0.9986244841815681],
#  [935, 0.998613037447989],
#  [936, 0.9998950792151925],
#  [937, 0.9991129509166173],
#  [938, 0.9991129509166173],
#  [939, 0.9932735426008968],
#  [940, 0.9473684210526315],
#  [941, 0.9986244841815681],
#  [942, 0.9970501474926253],
#  [943, 0.9090909090909091],
#  [944, 0.9992657856093979],
#  [945, 0.01762114537444934],
#  [946, 0.3076923076923077],
#  [947, 0.9991129509166173],
#  [948, 0.09090909090909091],
#  [949, 0.9971850809289233],
#  [950, 0.9991129509166173],
#  [951, 0.9803921568627452],
#  [952, 0.9950666008880118],
#  [953, 0.996240753466187],
#  [954, 0.9565217391304348],
#  [955, 0.9950666008880118],
#  [956, 0.8826197808019602],
#  [957, 0.9958506224066389],
#  [958, 0.9971850809289233],
#  [959, 0.9958506224066389],
#  [960, 0.9939759036144579],
#  [961, 0.9991129509166173],
#  [962, 0.9996552912788693],
#  [963, 0.9908814589665653],
#  [964, 0.9978354978354979],
#  [965, 0.9998950792151925],
#  [966, 0.9954751131221719],
#  [967, 0.996240753466187],
#  [968, 0.9977924944812362],
#  [969, 0.9998950792151925],
#  [970, 0.999810641923878],
#  [971, 0.9970501474926253],
#  [972, 0.999689537410742],
#  [973, 0.9971850809289233],
#  [974, 0.9991129509166173],
#  [975, 0.9991129509166173],
#  [976, 0.983402489626556],
#  [977, 0.9950666008880118],
#  [978, 0.9908256880733946],
#  [979, 0.9090909090909091],
#  [980, 0.9950666008880118],
#  [981, 0.9967845659163986],
#  [982, 0.9971850809289233],
#  [983, 0.9939759036144579],
#  [984, 0.9994478188845942],
#  [985, 0.9950666008880118],
#  [986, 0.09090909090909091],
#  [987, 0.996240753466187],
#  [988, 0.8235294117647058],
#  [989, 0.996240753466187],
#  [990, 0.01098901098901099],
#  [991, 0.9998950792151925],
#  [992, 0.9950666008880118],
#  [993, 0.9971098265895953],
#  [994, 0.9991129509166173],
#  [995, 0.9991129509166173],
#  [996, 0.9259259259259259],
#  [997, 0.9908814589665653],
#  [998, 0.9971850809289233],
#  [999, 0.9950666008880118],
#  ...]

# %%
def write_output(filename,results):
    out_file = open(filename,'w')
    count =0
    for line in results:
        output = str(line[0]) + "," + str(line[1]) + "\n"
        out_file.write(output)
    out_file.close()

# %%
def full_pipeline(output_name,train,test,N):
    train_data = prepare_data(train,N)
    model = train_model(train_data,N)
    choices = prepare_test_data(test,N)
    results = evaluate_model(model,choices)
    write_output(output_name,results)

# %%
full_pipeline("a_very_bold_trigram.csv","train.txt","test.txt",3)
