# %% [markdown]
# # Kaggle Competition Development Notebook

# %% [markdown]
# ### Import necessary libraries

# %%
import math
import pandas as pd
import numpy as np
import re
import time
import unicodedata as ud
import csv
import random
from sklearn.metrics import log_loss

# %% [markdown]
# # Import the vocab file

# %%
def create_vocab():
    with open('vocab.csv') as file:
        reader = csv.reader(file)
        vocab = list(reader)
    return vocab

# %% [markdown]
# ### Prep training data for N Gram Model

# %%
def prepare_data(filename, N):
    pre_string = "<s>"
    post_string = "</s>"
    train_dat = []
        
    with open(filename, encoding="utf8") as file:
        for line in file:
            line = ud.normalize("NFC",line)
            line = re.sub(' +',' ',line)
            line = re.sub('[,\.\?"“”]','',line)
            split_line = line.strip().split()
            for gram in range(1,N):
                split_line.insert(0,pre_string)
                split_line.append(post_string)
            train_dat.append(split_line)
    
    return train_dat

# %% [markdown]
# ## Create a test example from a training example

# %%
def create_test_example(training_line,word):
    if " " + word[0] + " " in training_line:
        new_str = ' {'+word[0]+"|"+word[1] + '} '
        test_line = re.sub(" " + word[0] + " ",new_str, training_line,1)
        test_line = re.sub("<s>","",test_line)
        test_line = re.sub("</s>","",test_line)
        prob = 1
        return test_line.strip(),prob
    elif " " + word[1] + " " in training_line:
        new_str = ' {'+word[0]+"|"+word[1] + '} '
        test_line = re.sub(" " + word[1] + " ",new_str, training_line,1)
        test_line = re.sub("<s>","",test_line)
        test_line = re.sub("</s>","",test_line)
        prob = 0
        return test_line.strip(),prob
    else:
        print("Error, word not found")

# %% [markdown]
# ## Determine which vocab word corresponds to location in the training data

# %%
def which_vocab(index):
    if index < 24200:
        return 0, 24200
    elif index < 48400:
        return 1, 24200
    elif index < 51290:
        return 2, 2890
    elif index < 75490:
        return 3, 24200
    elif index < 99690:
        return 4, 24200
    elif index < 123890:
        return 5, 24200
    elif index < 131159:
        return 6, 7269
    elif index < 155359:
        return 7, 24200
    elif index < 179559:
        return 8, 24200
    elif index < 203759:
        return 9, 24200
    elif index < 227959:
        return 10, 24200
    elif index < 252159:
        return 11, 24200
    elif index < 258227:
        return 12, 6068
    elif index < 282427:
        return 13, 24200
    elif index < 306627:
        return 14, 24200
    elif index < 310023:
        return 15, 3396
    elif index < 334223:
        return 16, 24200
    elif index < 358423:
        return 17, 24200
    elif index < 382623:
        return 18, 24200
    elif index < 406823:
        return 19, 24200
    elif index < 418928:
        return 20, 12105
    elif index < 430425:
        return 21, 11497
    elif index < 446988:
        return 22, 16563
    elif index < 452037:
        return 23, 5049
    elif index < 456571:
        return 24, 4534

# %% [markdown]
# ## Split the data into training and development
# #### Dev is saved to file, along with dev answers, new training array is returned

# %%
def train_dev_split(train_array, percent_split, vocab_df, dev_filename, answers_filename):
    dev_file = open(dev_filename,'w',encoding='utf8')
    dev_answers = open(answers_filename,'w',encoding='utf8')
    dev_answers.write("Id,Expected\n")
    new_train = []

    count = 1
    vocab_word = 0
    for index,training_line in enumerate(train_array):
        vocab_word, vocab_count = which_vocab(index)  
        if random.random() < percent_split/100:
            test_line, prob = create_test_example(" ".join(training_line),vocab_df[vocab_word])
            dev_answers.write(str(count) + "," + str(prob) + "\n")
            dev_file.write(test_line + "\n")
            count += 1
        else:
            new_train.append(training_line)
        
    dev_file.close()
    dev_answers.close()
    
    return new_train

# %% [markdown]
# ### Actually create the dictionary with all n-grams

# %%
def train_model(train_data, N):
    model = {}
    for line in train_data:
        for each_N in range(1,N+1):
            #for each line, generate all ngrams
            for index in range(0,len(line)-each_N):
                ngram = line[index]
                for n_forward in range(1,each_N):
                    ngram += ' ' + line[index+n_forward]
                if ngram in model:
                    model[ngram] += 1
                else:
                    model[ngram] = 1
    return model

# %% [markdown]
# ### Extract N-gram choices from the test data

# %%
def prepare_test_data(filename, N):
    choices=[]
    reg_exp_str = '\{(.*)\|(.*)\}'
    pre_string = ''
    post_string = ''
    for gram in range(1,N):
        pre_string += '<s> '
        post_string += ' </s>'
        if gram % 2 == 0:
            reg_exp_str = reg_exp_str + ' ([^ ]*)'
        else:
            reg_exp_str = '([^ ]*) ' + reg_exp_str
    
    reg_exp = re.compile(reg_exp_str)
    with open(filename, encoding="utf8") as file:
        for row in file:
            row = ud.normalize("NFC",row)
            row = re.sub(' +',' ',row)
            row = re.sub('[,\.\?"“”]','',row)
            row = pre_string + row.strip() + post_string
            #extract options
            match = reg_exp.search(row)
            if match:
                midpoint = math.ceil(N/2)
                choice_1 = match.group(midpoint)
                choice_2 = match.group(midpoint+1)
                for match_group in range(1,N+2):
                    if match_group < midpoint:
                        choice_1 = match.group(match_group) + ' ' + choice_1
                        choice_2 = match.group(match_group) + ' ' + choice_2
                    elif match_group > midpoint+1:
                        choice_1 += ' ' + match.group(match_group)
                        choice_2 += ' ' + match.group(match_group)
                choice = (choice_1, choice_2)
            else:
                print('error, no value')
                choice = 'error'
            choices.append(choice)
    return choices

# %% [markdown]
# ## Probability function to determine likelihood of option_1 and option_2

# %%
def backoff_probability(option_1,option_2,model):
    if option_1 in model:
        count_1 = model[option_1]
    else:
        count_1 = 0
        
    if option_2 in model:
        count_2 = model[option_2]
    else:
        count_2 = 0
    
    #if abs(count_1 - count_2) < 2:
    #if count_1 < 2 and count_2 < 2:
    if count_1 == 0 and count_2 == 0:
        split_1 = option_1.split()
        split_2 = option_2.split()
        if len(split_1) > 1 and len(split_2) > 1:
            if len(split_1) % 2 ==0:
                split_1.pop(0)
                split_2.pop(0)
            else:
                split_1.pop()
                split_2.pop()
            new_option_1 = " ".join(split_1)
            new_option_2 = " ".join(split_2)
            return basic_probability(new_option_1,new_option_2,model)
            
    elif count_1 == 0:
        count_1 = .1
    elif count_2 == 0:
        count_2 = .1
        
    prob_1 = count_1/(count_1+count_2)
    prob_2 = count_2/(count_1+count_2)
    
    return prob_1, prob_2

# %%
def basic_probability(option_1,option_2,model):
    if option_1 in model:
        count_1 = model[option_1]
    else:
        count_1 = 0
        
    if option_2 in model:
        count_2 = model[option_2]
    else:
        count_2 = 0
        
    if count_1 == 0 and count_2 == 0:
        count_1 = 1
        count_2 = 1    
    elif count_1 == 0:
        count_1 = .1
    elif count_2 == 0:
        count_2 = .1
        
    prob_1 = count_1/(count_1+count_2)
    prob_2 = count_2/(count_1+count_2)
    
    return prob_1, prob_2

# %%
def interpolate_probability(option_1,option_2,model,weights):
    prob_1_arr=[]
    prob_2_arr=[]
    n_option_1 = option_1
    n_option_2 = option_2
    
    while True:
        # get basic probabilty and add to overall
        c_prob_1, c_prob_2 = basic_probability(n_option_1,n_option_2,model)
        prob_1_arr.append(c_prob_1)
        prob_2_arr.append(c_prob_2)
        
        # split the options
        split_1 = n_option_1.split()
        split_2 = n_option_2.split()
        
        #get option lengths
        len_1 = len(split_1)
        len_2 = len(split_2)
        
        if len_1 <= 1 or len_2 <= 1:
            break
        
        if len(split_1) % 2 ==0:
            split_1.pop(0)
            split_2.pop(0)
        else:
            split_1.pop()
            split_2.pop()
        n_option_1 = " ".join(split_1)
        n_option_2 = " ".join(split_2)   
    
    #multiply probabilities by weights
    prob_1 = np.dot(weights,prob_1_arr)
    prob_2 = np.dot(weights,prob_2_arr)
    
    return prob_1, prob_2

# %%
start = time.time()
prob = interpolate_probability(choices[1][0],choices[1][1],model,[1,0,0])
end = time.time()
print(end-start, prob)
# Out:
# 0.00043773651123046875 (0.5, 0.5)

# %%
choices
# Out:
# [('ag a comhghleacaithe', 'ag á comhghleacaithe'),
#  ('Achta a thabhairt', 'Achta á thabhairt'),
#  ('Idirnáisiúnta a chomhlíonadh', 'Idirnáisiúnta á chomhlíonadh'),
#  ('Cé a sholáthródh', 'Cé á sholáthródh'),
#  ('seo a dhaingniú', 'seo á dhaingniú'),
#  ('agat a chur', 'agat á chur'),
#  ('airgeadais a thabhairt', 'airgeadais á thabhairt'),
#  ('rang a trí', 'rang á trí'),
#  ('ball a dhéanann', 'ball á dhéanann'),
#  ('aghaidh a thabhairt', 'aghaidh á thabhairt'),
#  ('aitheasc a thabhairt', 'aitheasc á thabhairt'),
#  ('nuair a bhí', 'nuair á bhí'),
#  ('éard a bhí', 'éard á bhí'),
#  ('euro a ghearradh', 'euro á ghearradh'),
#  ('scoláiriúil a thiomsaigh', 'scoláiriúil á thiomsaigh'),
#  ('cuairt a thabhairt', 'cuairt á thabhairt'),
#  ('agus a bhfuil', 'agus á bhfuil'),
#  ('fáth a mbíonn', 'fáth á mbíonn'),
#  ('speisialtóra a úsáid', 'speisialtóra á úsáid'),
#  ('athbhreithniú a dhéanamh', 'athbhreithniú á dhéanamh'),
#  ('haird a thabhairt', 'haird á thabhairt'),
#  ('é a bheith', 'é á bheith'),
#  ('nuachta a thaispeáint', 'nuachta á thaispeáint'),
#  ('bóthair a dhímheas', 'bóthair á dhímheas'),
#  ('rudaí a réiteach', 'rudaí á réiteach'),
#  ('bacadh a thuilleadh', 'bacadh á thuilleadh'),
#  ('daoine a roghnú;', 'daoine á roghnú;'),
#  ('mhaoin a meas', 'mhaoin á meas'),
#  ('Nuair a insíodh', 'Nuair á insíodh'),
#  ('Cad a tharlóidh', 'Cad á tharlóidh'),
#  ('staitisticí a raibh', 'staitisticí á raibh'),
#  ('neamhspleách a chur', 'neamhspleách á chur'),
#  ('Bhablóin a riail', 'Bhablóin á riail'),
#  ('deacair a shamhlú', 'deacair á shamhlú'),
#  ('hOstaire a reachtaíocht', 'hOstaire á reachtaíocht'),
#  ('mar a bhí', 'mar á bhí'),
#  ('Mar a Shamhlaítí', 'Mar á Shamhlaítí'),
#  ('ainm a bhí', 'ainm á bhí'),
#  ('aoise a hordaíodh', 'aoise á hordaíodh'),
#  ('sí a striapachas', 'sí á striapachas'),
#  ('minic a casadh', 'minic á casadh'),
#  ('córais a rialú', 'córais á rialú'),
#  ('éagsúlú a dhéanamh', 'éagsúlú á dhéanamh'),
#  ('luachmhar a shábháil', 'luachmhar á shábháil'),
#  ('Dheamhan a leithéid', 'Dheamhan á leithéid'),
#  ('sásta a bhí', 'sásta á bhí'),
#  ('comhairle a chur', 'comhairle á chur'),
#  ('gceist a thugann', 'gceist á thugann'),
#  ('Mar a léiríonn', 'Mar á léiríonn'),
#  ('fuinnimh a úsáid', 'fuinnimh á úsáid'),
#  ('iad a bhuachan', 'iad á bhuachan'),
#  ('deireanach a saolaíodh', 'deireanach á saolaíodh'),
#  ('sin a lean', 'sin á lean'),
#  ('Nuair a tharlaíonn', 'Nuair á tharlaíonn'),
#  ('dlí a chur', 'dlí á chur'),
#  ('é a chur', 'é á chur'),
#  ('rún a mhol', 'rún á mhol'),
#  ('fearr a thuigfí', 'fearr á thuigfí'),
#  ('is a seacht', 'is á seacht'),
#  ('Míoda a lorg', 'Míoda á lorg'),
#  ('achomharc a dhéanamh', 'achomharc á dhéanamh'),
#  ('creidiúnú a bhaint', 'creidiúnú á bhaint'),
#  ('ollmhór a chuir', 'ollmhór á chuir'),
#  ('beidh a ainm', 'beidh á ainm'),
#  ('tuairisc a thabhairt', 'tuairisc á thabhairt'),
#  ('scéalta a insint', 'scéalta á insint'),
#  ('uaire a chloig', 'uaire á chloig'),
#  ('páirt a ghlacadh', 'páirt á ghlacadh'),
#  ('gealltanas a tugadh', 'gealltanas á tugadh'),
#  ('taighde a léiriú', 'taighde á léiriú'),
#  ('bhfuil a fhios', 'bhfuil á fhios'),
#  ('stádas a mheabhraíonn', 'stádas á mheabhraíonn'),
#  ('mar a roghnaigh', 'mar á roghnaigh'),
#  ('muiníneach a dtiocfadh', 'muiníneach á dtiocfadh'),
#  ('foirne a mbeidh', 'foirne á mbeidh'),
#  ('do a bhfuil', 'do á bhfuil'),
#  ('mar a bheadh', 'mar á bheadh'),
#  ('mar a bhfuil', 'mar á bhfuil'),
#  ('deimhniú a thabharfar', 'deimhniú á thabharfar'),
#  ('mó a fhorbairt', 'mó á fhorbairt'),
#  ('phríomhaidhm a bheadh', 'phríomhaidhm á bheadh'),
#  ('Tairiscintí a lorg', 'Tairiscintí á lorg'),
#  ('teagmhála a fhreastalóidh', 'teagmhála á fhreastalóidh'),
#  ('bhfeirmeoireacht a rugadh', 'bhfeirmeoireacht á rugadh'),
#  ('ndiaidh a chéile', 'ndiaidh á chéile'),
#  ('Caoimhe a bheith', 'Caoimhe á bheith'),
#  ('rása a dhéanamh', 'rása á dhéanamh'),
#  ('éagsúla a chuireann', 'éagsúla á chuireann'),
#  ('comhaltaí a chosaint', 'comhaltaí á chosaint'),
#  ('daoine a bhí', 'daoine á bhí'),
#  ('dhaingean a dtig', 'dhaingean á dtig'),
#  ('Junior a throid', 'Junior á throid'),
#  ('mar a thagas', 'mar á thagas'),
#  ('té a bhfuil', 'té á bhfuil'),
#  ('cáilíichtaí a bhí', 'cáilíichtaí á bhí'),
#  ('meán a chomhshocraíonn', 'meán á chomhshocraíonn'),
#  ('nuaíochta a léamh', 'nuaíochta á léamh'),
#  ('ghiúróir a dúirt', 'ghiúróir á dúirt'),
#  ('as a lúb', 'as á lúb'),
#  ('cheart a bheith', 'cheart á bheith'),
#  ('eolais a chuir', 'eolais á chuir'),
#  ('eile a thaistil', 'eile á thaistil'),
#  ('uirlís a úsáidtear', 'uirlís á úsáidtear'),
#  ('Aibreán a bhí', 'Aibreán á bhí'),
#  ('cuairt a thabhairt', 'cuairt á thabhairt'),
#  ('bith a chur', 'bith á chur'),
#  ('foráil a dhéanamh', 'foráil á dhéanamh'),
#  ('seo a bhásaigh', 'seo á bhásaigh'),
#  ('inniu a dhearbhaíonn', 'inniu á dhearbhaíonn'),
#  ('corrfholúntais a líonadh', 'corrfholúntais á líonadh'),
#  ('anailís a leanas', 'anailís á leanas'),
#  ('seo a athrú', 'seo á athrú'),
#  ('Mar a tharlaíonn', 'Mar á tharlaíonn'),
#  ('phearsanta a scaoileadh', 'phearsanta á scaoileadh'),
#  ('saighdiúir a bheidh', 'saighdiúir á bheidh'),
#  ('thréigthe a fháil', 'thréigthe á fháil'),
#  ('eagraithe a chuirfidh', 'eagraithe á chuirfidh'),
#  ('ar a dtagtar', 'ar á dtagtar'),
#  ('Coitianta a Íoslódáil', 'Coitianta á Íoslódáil'),
#  ('dáta a roghnófar', 'dáta á roghnófar'),
#  ('ndéanann a comharsa', 'ndéanann á comharsa'),
#  ('raibh a n-úil', 'raibh á n-úil'),
#  ('rogáide a raibh', 'rogáide á raibh'),
#  ('teanga a shlánú', 'teanga á shlánú'),
#  ('is a fuaireamar', 'is á fuaireamar'),
#  ('iarraidh a ghealltanas', 'iarraidh á ghealltanas'),
#  ('céanna a bhí', 'céanna á bhí'),
#  ('conas a fheidhmíonn', 'conas á fheidhmíonn'),
#  ('raibh a fhios', 'raibh á fhios'),
#  ('siúd a bhí', 'siúd á bhí'),
#  ('Mar a phléann', 'Mar á phléann'),
#  ('cheird a fhoghlaim', 'cheird á fhoghlaim'),
#  ('fhreagracht a aistriú', 'fhreagracht á aistriú'),
#  ('comóradh a dhéanamh', 'comóradh á dhéanamh'),
#  ('ar a sáimhin', 'ar á sáimhin'),
#  ('srl a rá', 'srl á rá'),
#  ('Beidh a rogha', 'Beidh á rogha'),
#  ('tógtha a chur', 'tógtha á chur'),
#  ('cur a phíosa', 'cur á phíosa'),
#  ('éard a bhí', 'éard á bhí'),
#  ('é a bheith', 'é á bheith'),
#  ('nuair a bhíonn', 'nuair á bhíonn'),
#  ('oideachas a chur', 'oideachas á chur'),
#  ('rialacháin a dhéanamh', 'rialacháin á dhéanamh'),
#  ('ar a laghad', 'ar á laghad'),
#  ('ar a laghad', 'ar á laghad'),
#  ('Nuair a bhí', 'Nuair á bhí'),
#  ('leis a bheith', 'leis á bheith'),
#  ('daoine a dteastaíonn', 'daoine á dteastaíonn'),
#  ('ama a thógfaidh', 'ama á thógfaidh'),
#  ('as a laige', 'as á laige'),
#  ('dáta a fuair', 'dáta á fuair'),
#  ("péintéirí a d'oibrigh", "péintéirí á d'oibrigh"),
#  ('gnó a chlárú', 'gnó á chlárú'),
#  ('Leigheas a Dháileadh', 'Leigheas á Dháileadh'),
#  ('ar a raibh', 'ar á raibh'),
#  ('teanga a bhíonn', 'teanga á bhíonn'),
#  ('mar a gheall', 'mar á gheall'),
#  ('uair a gheobhas', 'uair á gheobhas'),
#  ('heolas a fuarthas', 'heolas á fuarthas'),
#  ('níl a fhios', 'níl á fhios'),
#  ("D'fhéadfaí a áiteamh", "D'fhéadfaí á áiteamh"),
#  ('aitheantas a thabhairt', 'aitheantas á thabhairt'),
#  ('chaoi a scríobhann', 'chaoi á scríobhann'),
#  ('allais a thomhas', 'allais á thomhas'),
#  ('choiste a bhaint', 'choiste á bhaint'),
#  ('chun a bfhreagra', 'chun á bfhreagra'),
#  ('sé a rá', 'sé á rá'),
#  ('té a bhfuil', 'té á bhfuil'),
#  ('samhla a áireamh', 'samhla á áireamh'),
#  ('thiománaithe a bhí', 'thiománaithe á bhí'),
#  ('EUR635 a íoc', 'EUR635 á íoc'),
#  ('(b) a cheangal', '(b) á cheangal'),
#  ('múinteoir a bheith', 'múinteoir á bheith'),
#  ('Eorpach a chosaint', 'Eorpach á chosaint'),
#  ('cheanglais a chomhlíonadh', 'cheanglais á chomhlíonadh'),
#  ('O1 a chomhlánú', 'O1 á chomhlánú'),
#  ('nuair a chuireamar', 'nuair á chuireamar'),
#  ('nuair a meascadh', 'nuair á meascadh'),
#  ('céanna a mhúnlaíonn', 'céanna á mhúnlaíonn'),
#  ('nua a fógraíodh', 'nua á fógraíodh'),
#  ('riosca a bhaineann', 'riosca á bhaineann'),
#  ('cad a tharla', 'cad á tharla'),
#  ('cinn a bhí', 'cinn á bhí'),
#  ('oifigeach a bheidh', 'oifigeach á bheidh'),
#  ('fáth a bhfuil', 'fáth á bhfuil'),
#  ('mionsonraithe a thabhairt', 'mionsonraithe á thabhairt'),
#  ('n-imeachtaí a ainmnítear', 'n-imeachtaí á ainmnítear'),
#  ('cláir a rinneadh', 'cláir á rinneadh'),
#  ('ag a raibh', 'ag á raibh'),
#  ('cearta a theorannú', 'cearta á theorannú'),
#  ('Nuair a bheas', 'Nuair á bheas'),
#  ('raibh a fhios', 'raibh á fhios'),
#  ('hÉirinn a hoibleagáidí', 'hÉirinn á hoibleagáidí'),
#  ('féin a chur', 'féin á chur'),
#  ('féidir a dhéanamh', 'féidir á dhéanamh'),
#  ("h'álainn a chara!", "h'álainn á chara!"),
#  ('tríocha a cúig', 'tríocha á cúig'),
#  ('cairde a fheiscint', 'cairde á fheiscint'),
#  ('Gaeilge a chéiliúradh', 'Gaeilge á chéiliúradh'),
#  ('nGall a rugadh', 'nGall á rugadh'),
#  ('Pleanála a bhunú', 'Pleanála á bhunú'),
#  ('slua a bheidh', 'slua á bheidh'),
#  ('DAB a bheith', 'DAB á bheith'),
#  ('bláthanna a ndí-cheall', 'bláthanna á ndí-cheall'),
#  ('bhfuil a fhios', 'bhfuil á fhios'),
#  ('éisteachta a mhealladhchuige', 'éisteachta á mhealladhchuige'),
#  ('Éire a bhualadh', 'Éire á bhualadh'),
#  ('choiste a chomóradh', 'choiste á chomóradh'),
#  ('€2423662 a íoc', '€2423662 á íoc'),
#  ('buile a thiomáint', 'buile á thiomáint'),
#  ('ordú a dhéanfaidh', 'ordú á dhéanfaidh'),
#  ('clóscríobhaí a bhí', 'clóscríobhaí á bhí'),
#  ('sin a ta', 'sin á ta'),
#  ('thaobh a chlé', 'thaobh á chlé'),
#  ('orm a bhí', 'orm á bhí'),
#  ('turasóireachta a chur', 'turasóireachta á chur'),
#  ('ceann a bhíonn', 'ceann á bhíonn'),
#  ('atá a scaoileadh', 'atá á scaoileadh'),
#  ('mholta a áireamh', 'mholta á áireamh'),
#  ('sí a ceathrú', 'sí á ceathrú'),
#  ('áirithe a dhéanamh', 'áirithe á dhéanamh'),
#  ('Chuaigh a hintinn', 'Chuaigh á hintinn'),
#  ('mar a tharlaíonn', 'mar á tharlaíonn'),
#  ('FSS a fháil', 'FSS á fháil'),
#  ('comóradh a dhéanamh', 'comóradh á dhéanamh'),
#  ('taighde a sheoladh', 'taighde á sheoladh'),
#  ('tSamhain a shíolraigh', 'tSamhain á shíolraigh'),
#  ('Gearmánacha a tháinig', 'Gearmánacha á tháinig'),
#  ('rud a mbíonn', 'rud á mbíonn'),
#  ('stríoc a chlárú', 'stríoc á chlárú'),
#  ('uair a bhfuil', 'uair á bhfuil'),
#  ('luíonn a mhacsamhail', 'luíonn á mhacsamhail'),
#  ('duine a rinne', 'duine á rinne'),
#  ('tionchar a bheidh', 'tionchar á bheidh'),
#  ('inathnuaite a fhorbairt', 'inathnuaite á fhorbairt'),
#  ('iarratas a dhéanamh', 'iarratas á dhéanamh'),
#  ('eolais a chur', 'eolais á chur'),
#  ('cumhachta a bheirtear', 'cumhachta á bheirtear'),
#  ('Liag a bhualadh', 'Liag á bhualadh'),
#  ('féidir a fheiceáil', 'féidir á fheiceáil'),
#  ('seacláid a leá', 'seacláid á leá'),
#  ('meánleibhéal a tionóladh', 'meánleibhéal á tionóladh'),
#  ('fearran a togadh', 'fearran á togadh'),
#  ('shíne a fháil', 'shíne á fháil'),
#  ('coiscín a chur', 'coiscín á chur'),
#  ('Ghaeilge) a dhéanamh63', 'Ghaeilge) á dhéanamh63'),
#  ('sin a bhí', 'sin á bhí'),
#  ('gceist a fhreagairt', 'gceist á fhreagairt'),
#  ('is a bhí', 'is á bhí'),
#  ('leithscéal a Niall', 'leithscéal á Niall'),
#  ('raibh a fhios', 'raibh á fhios'),
#  ('seo a leanas', 'seo á leanas'),
#  ('mheicneora a bheadhmar', 'mheicneora á bheadhmar'),
#  ('Choimisiún a thuilleadh', 'Choimisiún á thuilleadh'),
#  ('WEEE a chur', 'WEEE á chur'),
#  ('Pumpsie a ndéanann', 'Pumpsie á ndéanann'),
#  ('duine a dhéanfas', 'duine á dhéanfas'),
#  ('Spreagadh a thabhairt', 'Spreagadh á thabhairt'),
#  ('http://wwwtheregistercouk/2013/05/10/oh_no_its_the_plastic_3d_gun/ a mhínigh',
#   'http://wwwtheregistercouk/2013/05/10/oh_no_its_the_plastic_3d_gun/ á mhínigh'),
#  ('iad a éileamh', 'iad á éileamh'),
#  ('Sochair a Bhaineann', 'Sochair á Bhaineann'),
#  ('ceangal a dhéanamh', 'ceangal á dhéanamh'),
#  ('mór a bheadh', 'mór á bheadh'),
#  ('lucht a léite', 'lucht á léite'),
#  ('é a bheith', 'é á bheith'),
#  ('iomchuí a ghlacadh', 'iomchuí á ghlacadh'),
#  ('suíochán a bhaint', 'suíochán á bhaint'),
#  ('raibhe a bhforthainn', 'raibhe á bhforthainn'),
#  ('mar a tharlaíonn', 'mar á tharlaíonn'),
#  ('uile a bhféadfadh', 'uile á bhféadfadh'),
#  ('Suibhne a mharaigh', 'Suibhne á mharaigh'),
#  ('sin a shamhlú', 'sin á shamhlú'),
#  ('Mar a deir', 'Mar á deir'),
#  ('bhun a tóna', 'bhun á tóna'),
#  ('rianpháipéar a úsáid', 'rianpháipéar á úsáid'),
#  ('tosaíochtaí a bheidh', 'tosaíochtaí á bheidh'),
#  ('anois a Eoghain', 'anois á Eoghain'),
#  ('fhile a chur', 'fhile á chur'),
#  ('seit a dhéanamh', 'seit á dhéanamh'),
#  ('himlitreacha a luaitear', 'himlitreacha á luaitear'),
#  ('taosrán a fhágáil', 'taosrán á fhágáil'),
#  ("'Strus a Cheannfoirt'", "'Strus á Cheannfoirt'"),
#  ('raibh a dhath', 'raibh á dhath'),
#  ('ar a mbeartais', 'ar á mbeartais'),
#  ('Europol a thaisceadh', 'Europol á thaisceadh'),
#  ('seo a bhféadfadh', 'seo á bhféadfadh'),
#  ('as a dTuarascáil', 'as á dTuarascáil'),
#  ('meas a bhí', 'meas á bhí'),
#  ('comhbhá a mhúscailt', 'comhbhá á mhúscailt'),
#  ('mbeifeá a cheannach', 'mbeifeá á cheannach'),
#  ('bhfear a thug', 'bhfear á thug'),
#  ('nuair a bunaíodh', 'nuair á bunaíodh'),
#  ('fo-fheachtais a áireamh', 'fo-fheachtais á áireamh'),
#  ('seo a fhanfaidh', 'seo á fhanfaidh'),
#  ('mé a rá', 'mé á rá'),
#  ('dalta a bhíonn', 'dalta á bhíonn'),
#  ('páirt a ghlacadh', 'páirt á ghlacadh'),
#  ('beaga a chniotáil', 'beaga á chniotáil'),
#  ('daoine a bhí', 'daoine á bhí'),
#  ('fear a mhúineann', 'fear á mhúineann'),
#  ('chun a gcuid', 'chun á gcuid'),
#  ('seo a leanas', 'seo á leanas'),
#  ('achomharc a dhéanamh', 'achomharc á dhéanamh'),
#  ('liom a dhath', 'liom á dhath'),
#  ('nua a dhéanamh', 'nua á dhéanamh'),
#  ('iad a bheith', 'iad á bheith'),
#  ("guth a d'fhág", "guth á d'fhág"),
#  ('gcomhlíonadh a cúraimí', 'gcomhlíonadh á cúraimí'),
#  ('SF a dhéanamh', 'SF á dhéanamh'),
#  ('ar a gcuid', 'ar á gcuid'),
#  ('choirn a bhuadar', 'choirn á bhuadar'),
#  ("biadh a d'ith", "biadh á d'ith"),
#  ('foirne a fhaigheann', 'foirne á fhaigheann'),
#  ('deacair a rá', 'deacair á rá'),
#  ("Valera a d'iarr", "Valera á d'iarr"),
#  ('é a Tacaíonn', 'é á Tacaíonn'),
#  ('dúshlán a bheidh', 'dúshlán á bheidh'),
#  ('acomhal a dhéanamh', 'acomhal á dhéanamh'),
#  ('sé a eachtraí', 'sé á eachtraí'),
#  ('dalta a bheith', 'dalta á bheith'),
#  ('ionannú a dhéanamh', 'ionannú á dhéanamh'),
#  ('seo a rith', 'seo á rith'),
#  ('cheart a thabhairt', 'cheart á thabhairt'),
#  ('poitéinsiúil a chaill', 'poitéinsiúil á chaill'),
#  ('chuige a bhí', 'chuige á bhí'),
#  ('Eo a bhí', 'Eo á bhí'),
#  ('céanna a dhéanamh', 'céanna á dhéanamh'),
#  ('leabhar a scríobh', 'leabhar á scríobh'),
#  ('daonna a chomhlíonann', 'daonna á chomhlíonann'),
#  ('stad a chur', 'stad á chur'),
#  ('leighis a phleanáil', 'leighis á phleanáil'),
#  ('cruinne a rá', 'cruinne á rá'),
#  ('Siopa a bheith', 'Siopa á bheith'),
#  ('feabhsuithe a fheiceáil', 'feabhsuithe á fheiceáil'),
#  ('Múinteoir a thuigeann', 'Múinteoir á thuigeann'),
#  ('gloine a oscailt', 'gloine á oscailt'),
#  ('díol a gcapall', 'díol á gcapall'),
#  ('féidir a dhéanadh', 'féidir á dhéanadh'),
#  ('Rud a bhí', 'Rud á bhí'),
#  ('tithíochta a oireann', 'tithíochta á oireann'),
#  ('Meiriceá a thosaigh', 'Meiriceá á thosaigh'),
#  ('seo a leanas:', 'seo á leanas:'),
#  ('Kennedy a thosaigh', 'Kennedy á thosaigh'),
#  ('agus a thaispeántar', 'agus á thaispeántar'),
#  ('éalú a bhí', 'éalú á bhí'),
#  ('Nuair a bhraitheann', 'Nuair á bhraitheann'),
#  ('cheart a fháil', 'cheart á fháil'),
#  ('Focail a bhaineann', 'Focail á bhaineann'),
#  ('Chomhphobail a ghlacadh', 'Chomhphobail á ghlacadh'),
#  ('siúd a mbaineann', 'siúd á mbaineann'),
#  ('nuair a cuirfar', 'nuair á cuirfar'),
#  ('taifid a choinneáil', 'taifid á choinneáil'),
#  ('meas a bheith', 'meas á bheith'),
#  ('meas a bheith', 'meas á bheith'),
#  ('Áitiúil a sheol', 'Áitiúil á sheol'),
#  ('coiriúlacht a chosc', 'coiriúlacht á chosc'),
#  ('di a bheith', 'di á bheith'),
#  ('Gaeilge a aithris', 'Gaeilge á aithris'),
#  ('ginearálta a fhorbairt', 'ginearálta á fhorbairt'),
#  ('breathnóirí a théann', 'breathnóirí á théann'),
#  ('seo a bhainistiú', 'seo á bhainistiú'),
#  ('ionstraimí a bhféadfadh', 'ionstraimí á bhféadfadh'),
#  ('as a deich', 'as á deich'),
#  ('mar a bhíonn', 'mar á bhíonn'),
#  ('Tá a stíl', 'Tá á stíl'),
#  ('saoránach a roghnaíonn', 'saoránach á roghnaíonn'),
#  ('dóigh a bhfuil', 'dóigh á bhfuil'),
#  ('achtúireacha a thagann', 'achtúireacha á thagann'),
#  ('nuair a bhíodar', 'nuair á bhíodar'),
#  ('raibh a fhios', 'raibh á fhios'),
#  ('rialacha a ghlacadh', 'rialacha á ghlacadh'),
#  ('minic a thaispeántar', 'minic á thaispeántar'),
#  ('heagrais a léirigh', 'heagrais á léirigh'),
#  ('McGuinness a aistriú', 'McGuinness á aistriú'),
#  ('gairid a chruthú', 'gairid á chruthú'),
#  ('focail a thabhairt', 'focail á thabhairt'),
#  ('litríocht a chuireanns', 'litríocht á chuireanns'),
#  ('is a bhí', 'is á bhí'),
#  ('Chlár a bheas', 'Chlár á bheas'),
#  ('orthu a tuilleadh', 'orthu á tuilleadh'),
#  ('ar a laghad', 'ar á laghad'),
#  ('ndaltaí a chlárú', 'ndaltaí á chlárú'),
#  ('ar a tuilleamh', 'ar á tuilleamh'),
#  ('Tomhaltóirí a Fhorfheidhmiú)', 'Tomhaltóirí á Fhorfheidhmiú)'),
#  ('ar a 1-30', 'ar á 1-30'),
#  ('Nuair a tharlaíonn', 'Nuair á tharlaíonn'),
#  ("scéal a d'insíodh", "scéal á d'insíodh"),
#  ('náisiúnta a chur', 'náisiúnta á chur'),
#  ('fear a mbeadh', 'fear á mbeadh'),
#  ('scrúduithe a déanfar', 'scrúduithe á déanfar'),
#  ('nuair a fheiceann', 'nuair á fheiceann'),
#  ('gCeanada a thír', 'gCeanada á thír'),
#  ('iniúctha a asbhaint', 'iniúctha á asbhaint'),
#  ('ann a dhéanamh', 'ann á dhéanamh'),
#  ('Shonraithe a úsáideann', 'Shonraithe á úsáideann'),
#  ('sin a chloisteáil!', 'sin á chloisteáil!'),
#  ('éigean a bheadh', 'éigean á bheadh'),
#  ('modh a úsáidfear', 'modh á úsáidfear'),
#  ('chás a chur', 'chás á chur'),
#  ('dlí a bheadh', 'dlí á bheadh'),
#  ('seo a reáchtáiltear', 'seo á reáchtáiltear'),
#  ('nasctha a chur', 'nasctha á chur'),
#  ('acmhainní a bhí', 'acmhainní á bhí'),
#  ('seo a choinneáil', 'seo á choinneáil'),
#  ('daonna a raibh', 'daonna á raibh'),
#  ('Loingsigh a bhí', 'Loingsigh á bhí'),
#  ('beag a scríobh', 'beag á scríobh'),
#  ('uisce a chur', 'uisce á chur'),
#  ('fiúntas a bheadh', 'fiúntas á bheadh'),
#  ('agus a chéile', 'agus á chéile'),
#  ('bhfeachtas a neartú', 'bhfeachtas á neartú'),
#  ('iad a roinnt', 'iad á roinnt'),
#  ('ceiliúradh a gcéad', 'ceiliúradh á gcéad'),
#  ('luxe a gcumhrán', 'luxe á gcumhrán'),
#  ('ag a 800in', 'ag á 800in'),
#  ('Utd a ghlacadh', 'Utd á ghlacadh'),
#  ('chúnaimh a thugtar', 'chúnaimh á thugtar'),
#  ('Rang a 5', 'Rang á 5'),
#  ('teicneolaíochta a reic', 'teicneolaíochta á reic'),
#  ('brabús a roinnt', 'brabús á roinnt'),
#  ('fós a cur', 'fós á cur'),
#  ('Glas-stócach a gníos', 'Glas-stócach á gníos'),
#  ('dráma a chleachtadh', 'dráma á chleachtadh'),
#  ('deireadh a chur', 'deireadh á chur'),
#  ('eile a chéad', 'eile á chéad'),
#  ('mar a dhéiléalfaí', 'mar á dhéiléalfaí'),
#  ('Dhia a bhí', 'Dhia á bhí'),
#  ('dúlagar a bheith', 'dúlagar á bheith'),
#  ('bhealach a chuir', 'bhealach á chuir'),
#  ('téagartha a scríobhtar', 'téagartha á scríobhtar'),
#  ('forbhreathnú a fháil', 'forbhreathnú á fháil'),
#  ('XIV a ghabhann', 'XIV á ghabhann'),
#  ('feabhas a bradáin', 'feabhas á bradáin'),
#  ('libh a rá', 'libh á rá'),
#  ('mé a rá', 'mé á rá'),
#  ('mhiotal a dhealú', 'mhiotal á dhealú'),
#  ('speisialta a dhéanfar', 'speisialta á dhéanfar'),
#  ('acmhainne a mheas:', 'acmhainne á mheas:'),
#  ('breise a dhéanamh', 'breise á dhéanamh'),
#  ('gearrán a fhreagairt!', 'gearrán á fhreagairt!'),
#  ('é a chuir', 'é á chuir'),
#  ('atá a chur', 'atá á chur'),
#  ('(c) a agróidh', '(c) á agróidh'),
#  ('síos a dhéanamh', 'síos á dhéanamh'),
#  ('mbrúghrúpaí a chur', 'mbrúghrúpaí á chur'),
#  ('hÉireannaigh a thuiscint', 'hÉireannaigh á thuiscint'),
#  ('mbarr a ghoib', 'mbarr á ghoib'),
#  ('nuair a bhí', 'nuair á bhí'),
#  ('piléar a mharaigh', 'piléar á mharaigh'),
#  ('cuardaigh a bheith', 'cuardaigh á bheith'),
#  ('agus a chuid', 'agus á chuid'),
#  ('traenála a d‟fhéadfadh', 'traenála á d‟fhéadfadh'),
#  ('Gnólacht a Mheasúnú', 'Gnólacht á Mheasúnú'),
#  ('réir a chéile', 'réir á chéile'),
#  ('oideachais a fuair', 'oideachais á fuair'),
#  ('<s> a d', '<s> á d'),
#  ('in a harsh', 'in á harsh'),
#  ('Comhleá a Fhorbairt', 'Comhleá á Fhorbairt'),
#  ('airgeadais a fhorbairt', 'airgeadais á fhorbairt'),
#  ('cuairt a thabhairt', 'cuairt á thabhairt'),
#  ('béim a chur', 'béim á chur'),
#  ('rudaí a sheachadadh', 'rudaí á sheachadadh'),
#  ('bromastúin a bhí', 'bromastúin á bhí'),
#  ('oibre a dhéantar', 'oibre á dhéantar'),
#  ('Gabriel a chuir', 'Gabriel á chuir'),
#  ('dream a íonsaí', 'dream á íonsaí'),
#  ('fad a rinne', 'fad á rinne'),
#  ('nuair a bheidh', 'nuair á bheidh'),
#  ('áit a gceistítear', 'áit á gceistítear'),
#  ('iarratas a dhéanamh', 'iarratas á dhéanamh'),
#  ('Guy a thagann', 'Guy á thagann'),
#  ('Olc a phlotáil', 'Olc á phlotáil'),
#  ('crua a fuair', 'crua á fuair'),
#  ('lá a thabhairt', 'lá á thabhairt'),
#  ('ní a choimeádann', 'ní á choimeádann'),
#  ('ama a chaithfeadh', 'ama á chaithfeadh'),
#  ('smacht a ghlacadh', 'smacht á ghlacadh'),
#  ('fola a bhí', 'fola á bhí'),
#  ('fearr a fháil', 'fearr á fháil'),
#  ('mar a shíltear', 'mar á shíltear'),
#  ('deireadh a chur', 'deireadh á chur'),
#  ('suíochán a thairiscint', 'suíochán á thairiscint'),
#  ('nuair a nár', 'nuair á nár'),
#  ('nó a bheidh', 'nó á bheidh'),
#  ('staire a bhí', 'staire á bhí'),
#  ('Pobail a chosaint', 'Pobail á chosaint'),
#  ('phobail a bhí', 'phobail á bhí'),
#  ('teile-leighis a sholáthar', 'teile-leighis á sholáthar'),
#  ('cinneadh a dhéanamh', 'cinneadh á dhéanamh'),
#  ('aschur a rialú', 'aschur á rialú'),
#  ('nuair a léifidh', 'nuair á léifidh'),
#  ('oibre a chur', 'oibre á chur'),
#  ('dramhaíola a bheith', 'dramhaíola á bheith'),
#  ('duine a sháróidh', 'duine á sháróidh'),
#  ('rud a fhanfaidh', 'rud á fhanfaidh'),
#  ('comhairle a chur', 'comhairle á chur'),
#  ('é a hathair', 'é á hathair'),
#  ('ealaíon a phobal', 'ealaíon á phobal'),
#  ('breise a theastaíonn', 'breise á theastaíonn'),
#  ('seo a leanas', 'seo á leanas'),
#  ('daonna a dhoimhniú', 'daonna á dhoimhniú'),
#  ('scoil a Thomáis', 'scoil á Thomáis'),
#  ("'Tú a chur", "'Tú á chur"),
#  ('ar a shocairshuaimhneas', 'ar á shocairshuaimhneas'),
#  ('athbhreithniú a luaithe', 'athbhreithniú á luaithe'),
#  ('ndaoine a bhfuil', 'ndaoine á bhfuil'),
#  ('nuair a ghníomhóidh', 'nuair á ghníomhóidh'),
#  ('ar a laghad', 'ar á laghad'),
#  ('nuair a chuaidh', 'nuair á chuaidh'),
#  ('buaile a bhaineann', 'buaile á bhaineann'),
#  ('dochrach a chaolú', 'dochrach á chaolú'),
#  ('sin a bheith', 'sin á bheith'),
#  ('agaibhse a chreideann', 'agaibhse á chreideann'),
#  ('agus a bhfuil', 'agus á bhfuil'),
#  ('rum a chur', 'rum á chur'),
#  ('Seoighe) a scríobh', 'Seoighe) á scríobh'),
#  ('liúdramán a thabhairt', 'liúdramán á thabhairt'),
#  ('SULT a bhaint', 'SULT á bhaint'),
#  ('rud a léiríonn', 'rud á léiríonn'),
#  ('spriocghrúpa a raibh', 'spriocghrúpa á raibh'),
#  ('bean a bhfuil', 'bean á bhfuil'),
#  ('ann a gheobhfainn', 'ann á gheobhfainn'),
#  ('Gaeilge a normalú', 'Gaeilge á normalú'),
#  ('fear a bhí', 'fear á bhí'),
#  ('scoláirí a mhealladh', 'scoláirí á mhealladh'),
#  ('oifigigh a bheidh', 'oifigigh á bheidh'),
#  ('bithóipse a fháil', 'bithóipse á fháil'),
#  ('Mhuineacháin a rugadh', 'Mhuineacháin á rugadh'),
#  ('deacrachtaí a ghabhann', 'deacrachtaí á ghabhann'),
#  ('iarraidh a fháil', 'iarraidh á fháil'),
#  ('Céard a mhaith', 'Céard á mhaith'),
#  ('é a phógadh', 'é á phógadh'),
#  ('mar a fheictear', 'mar á fheictear'),
#  ('mar a dhéanfadh', 'mar á dhéanfadh'),
#  ('sé a thástáil', 'sé á thástáil'),
#  ('sprioc a leagamar', 'sprioc á leagamar'),
#  ('singil a láimhseáil', 'singil á láimhseáil'),
#  ('comrádaí a bhí', 'comrádaí á bhí'),
#  ('misean a chosaint', 'misean á chosaint'),
#  ('Coimisiún a mholadh', 'Coimisiún á mholadh'),
#  ('mar a taispeántar', 'mar á taispeántar'),
#  ('sciodair a ghluaiseann', 'sciodair á ghluaiseann'),
#  ('eile a fheidhmiú', 'eile á fheidhmiú'),
#  ('shinsearacha a rogha', 'shinsearacha á rogha'),
#  ('liúntas a íoc', 'liúntas á íoc'),
#  ('tá a fhios', 'tá á fhios'),
#  ('scuabadh a dhíth', 'scuabadh á dhíth'),
#  ('feirme a fháil—', 'feirme á fháil—'),
#  ('talamh a luíonn', 'talamh á luíonn'),
#  ('cé a bheadh', 'cé á bheadh'),
#  ('phobail a chur', 'phobail á chur'),
#  ('Zhivago a rinne', 'Zhivago á rinne'),
#  ('scoile a oibríonn', 'scoile á oibríonn'),
#  ('Nuair a bhíonn', 'Nuair á bhíonn'),
#  ('coinne a dhéanamh', 'coinne á dhéanamh'),
#  ('cúiseanna a thug', 'cúiseanna á thug'),
#  ('seo a leanas', 'seo á leanas'),
#  ('nuair a fuair', 'nuair á fuair'),
#  ('Peadar a scríobh', 'Peadar á scríobh'),
#  ('dátaí a lua', 'dátaí á lua'),
#  ('sin a ainm', 'sin á ainm'),
#  ('nuair a fhágfas', 'nuair á fhágfas'),
#  ('tú a bheith', 'tú á bheith'),
#  ('nuair a bhí', 'nuair á bhí'),
#  ('tomhaiste a úsáid', 'tomhaiste á úsáid'),
#  ('chaill a bhrí', 'chaill á bhrí'),
#  ('leitheadaí a fháil', 'leitheadaí á fháil'),
#  ('tuairisc a chur', 'tuairisc á chur'),
#  ('scéalta a chuir', 'scéalta á chuir'),
#  ('Sin a bhí', 'Sin á bhí'),
#  ('labhartha a chur', 'labhartha á chur'),
#  ('dhrochghortú a bhain', 'dhrochghortú á bhain'),
#  ('lipadú a dhéanamh', 'lipadú á dhéanamh'),
#  ('moltaí a fháil', 'moltaí á fháil'),
#  ('Bean a bhfuil', 'Bean á bhfuil'),
#  ('mheabhrán a sheachadfar', 'mheabhrán á sheachadfar'),
#  ('chun a dheimhniú', 'chun á dheimhniú'),
#  ('dhochrach a imirt', 'dhochrach á imirt'),
#  ('féidir a shamlú', 'féidir á shamlú'),
#  ('díospóireachta a fheiceáil', 'díospóireachta á fheiceáil'),
#  ('fiosruithe a dhéanamh', 'fiosruithe á dhéanamh'),
#  ('sráideanna a ainmníodh', 'sráideanna á ainmníodh'),
#  ('féidir a léiriú', 'féidir á léiriú'),
#  ('ndícheall a dhéanamh', 'ndícheall á dhéanamh'),
#  ('siúd a bhí', 'siúd á bhí'),
#  ('fiúntacha a chur', 'fiúntacha á chur'),
#  ('Birtill a thicéad', 'Birtill á thicéad'),
#  ('Mhuigheó a dháileadh', 'Mhuigheó á dháileadh'),
#  ('aghaidh a thabhairt', 'aghaidh á thabhairt'),
#  ('ionadaithe a chur', 'ionadaithe á chur'),
#  ('1983 a ghairm', '1983 á ghairm'),
#  ('seo a leanas', 'seo á leanas'),
#  ('coincheapanna a bhí', 'coincheapanna á bhí'),
#  ('fuilteach a throid', 'fuilteach á throid'),
#  ('dhorcha a bhí', 'dhorcha á bhí'),
#  ('rathúlacht a bhaint', 'rathúlacht á bhaint'),
#  ('gnéis a dhéanamh', 'gnéis á dhéanamh'),
#  ('éis a bheith', 'éis á bheith'),
#  ('dóigh a chuaigh', 'dóigh á chuaigh'),
#  ('é a bhí', 'é á bhí'),
#  ('ceoil a bheadh', 'ceoil á bheadh'),
#  ('mar a bhí', 'mar á bhí'),
#  ('–focail a bhfuil', '–focail á bhfuil'),
#  ('cheart a dhéanamh', 'cheart á dhéanamh'),
#  ('riabhach a bhfeadar', 'riabhach á bhfeadar'),
#  ('atá a ullmhú', 'atá á ullmhú'),
#  ('Jó a bhéas', 'Jó á bhéas'),
#  ('teastaíonn a chúig', 'teastaíonn á chúig'),
#  ('úsáideoirí a dhearadh', 'úsáideoirí á dhearadh'),
#  ('Rud a chabhróidh', 'Rud á chabhróidh'),
#  ('áit a bhí', 'áit á bhí'),
#  ('sin a leamh!!', 'sin á leamh!!'),
#  ('Onnmhairí a Rialú', 'Onnmhairí á Rialú'),
#  ('nó a athrach)', 'nó á athrach)'),
#  ('praiticiúla a dhéanamh', 'praiticiúla á dhéanamh'),
#  ('nua a tháirgeadh', 'nua á tháirgeadh'),
#  ('torthaí a chuid', 'torthaí á chuid'),
#  ('ná a bhíodh', 'ná á bhíodh'),
#  ('Government a foilsíodh', 'Government á foilsíodh'),
#  ('tréitheach a bhí', 'tréitheach á bhí'),
#  ('Iúil a bheidh', 'Iúil á bheidh'),
#  ('ar a dtug', 'ar á dtug'),
#  ('seomrach a bhí', 'seomrach á bhí'),
#  ('Ceisteanna a eascraíonn', 'Ceisteanna á eascraíonn'),
#  ('fir a mharaigh', 'fir á mharaigh'),
#  ('uilig a thugann', 'uilig á thugann'),
#  ('Michelle a mhúineann', 'Michelle á mhúineann'),
#  ('áitiúil a bheith', 'áitiúil á bheith'),
#  ('seo a mhoitheailt', 'seo á mhoitheailt'),
#  ('seansanna a thógaint', 'seansanna á thógaint'),
#  ('feidhmíochta a úsáidfear', 'feidhmíochta á úsáidfear'),
#  ('breithiúnach a eisiúint', 'breithiúnach á eisiúint'),
#  ('Mar a dúirt', 'Mar á dúirt'),
#  ('tacaíocht a dtabhairt', 'tacaíocht á dtabhairt'),
#  ('liom a fhoglaim', 'liom á fhoglaim'),
#  ('dánta a scríobhamar!', 'dánta á scríobhamar!'),
#  ('ardú a cinn', 'ardú á cinn'),
#  ('ceallra a choinníonn', 'ceallra á choinníonn'),
#  ('Mar a luaigh', 'Mar á luaigh'),
#  ('fhaisnéis a bheith', 'fhaisnéis á bheith'),
#  ('Honest a Mhuraed', 'Honest á Mhuraed'),
#  ('300 a bheidh', '300 á bheidh'),
#  ("``hEireann'' a chur", "``hEireann'' á chur"),
#  ('airgead a bheidh', 'airgead á bheidh'),
#  ('scrúdú a dhéanamh', 'scrúdú á dhéanamh'),
#  ('nó a ordóidh', 'nó á ordóidh'),
#  ('amháin a chruthú', 'amháin á chruthú'),
#  ('rud a déarfadh', 'rud á déarfadh'),
#  ('agat a Fhearn', 'agat á Fhearn'),
#  ('Carnann a chuid', 'Carnann á chuid'),
#  ('príomhchathair a bhogadh', 'príomhchathair á bhogadh'),
#  ('raibh a fhios', 'raibh á fhios'),
#  ('meas a bhí', 'meas á bhí'),
#  ("daoine a d'fhreastail", "daoine á d'fhreastail"),
#  ('Chun a chumasú', 'Chun á chumasú'),
#  ('liom a leithéid', 'liom á leithéid'),
#  ('meáin a bheith', 'meáin á bheith'),
#  ('tsíorlíomhain a bhíodh', 'tsíorlíomhain á bhíodh'),
#  ('sin a bhraithimse', 'sin á bhraithimse'),
#  ('chaoi a thabharfaidh', 'chaoi á thabharfaidh'),
#  ('inbhuanaithe a chruthú', 'inbhuanaithe á chruthú'),
#  ('deor a chaoineadh', 'deor á chaoineadh'),
#  ('Céard a dúirt', 'Céard á dúirt'),
#  ('líne a dhéanamh', 'líne á dhéanamh'),
#  ('fhógra a chaithfidh', 'fhógra á chaithfidh'),
#  ('(a) a ordú', '(a) á ordú'),
#  ('Mar a dúirt', 'Mar á dúirt'),
#  ('tosaigh a bhí', 'tosaigh á bhí'),
#  ('faisnéis a fhoilsítear', 'faisnéis á fhoilsítear'),
#  ('rómánsach a bhí', 'rómánsach á bhí'),
#  ('thuismitheoirí a thabhairt', 'thuismitheoirí á thabhairt'),
#  ('Mar a dúirt', 'Mar á dúirt'),
#  ('olltoghchán a bhí', 'olltoghchán á bhí'),
#  ('sonraí a choimeád', 'sonraí á choimeád'),
#  ('athchuimhne a rinne', 'athchuimhne á rinne'),
#  ('chuideachta a dtarlóidh', 'chuideachta á dtarlóidh'),
#  ('gconraitheoir a chuireann', 'gconraitheoir á chuireann'),
#  ('fad a bhaineann', 'fad á bhaineann'),
#  ('rud a deirim', 'rud á deirim'),
#  ('fhoireann a láidriú', 'fhoireann á láidriú'),
#  ('ceol a sheanathar', 'ceol á sheanathar'),
#  ('fhear a raibh', 'fhear á raibh'),
#  ('costais a bhain', 'costais á bhain'),
#  ('2005 a reáchtáladh', '2005 á reáchtáladh'),
#  ('gearán a dhéanamh', 'gearán á dhéanamh'),
#  ("mise a d'iompródh", "mise á d'iompródh"),
#  ('eile a chur', 'eile á chur'),
#  ('bhrí a shanntar', 'bhrí á shanntar'),
#  ('bharr a shuíomh', 'bharr á shuíomh'),
#  ('(b) a mhéid', '(b) á mhéid'),
#  ('Nuair a thagann', 'Nuair á thagann'),
#  ('aithbhreithniú a dhéanamh', 'aithbhreithniú á dhéanamh'),
#  ('éadrom a bhíonn', 'éadrom á bhíonn'),
#  ('Tá a fhios', 'Tá á fhios'),
#  ('tuairisc a fuair', 'tuairisc á fuair'),
#  ('baileach a tharraing', 'baileach á tharraing'),
#  ('ceardchumainn a dhéanann', 'ceardchumainn á dhéanann'),
#  ('tugadh a ainm', 'tugadh á ainm'),
#  ('Chraobh a shroichint', 'Chraobh á shroichint'),
#  ('phoiblí a chur', 'phoiblí á chur'),
#  ('is a thugann', 'is á thugann'),
#  ('méid a thug', 'méid á thug'),
#  ('ar a bhfuil', 'ar á bhfuil'),
#  ('seo a bhíonn', 'seo á bhíonn'),
#  ('strainséirí a raibh', 'strainséirí á raibh'),
#  ('scata a bhí', 'scata á bhí'),
#  ('páirt a ghlacadh', 'páirt á ghlacadh'),
#  ('mar a nochtar', 'mar á nochtar'),
#  ('rud a chinntíonn', 'rud á chinntíonn'),
#  ('ann a roghnú', 'ann á roghnú'),
#  ('nuair a chuaigh', 'nuair á chuaigh'),
#  ('MISNEACH a spreagadh', 'MISNEACH á spreagadh'),
#  ('Séamus a bhí', 'Séamus á bhí'),
#  ('eile a ghineann', 'eile á ghineann'),
#  ('é a dhéanamh', 'é á dhéanamh'),
#  ('hanlaí a dhaingniú', 'hanlaí á dhaingniú'),
#  ('Gaeilge a mhalairt', 'Gaeilge á mhalairt'),
#  ('anocht a chairde', 'anocht á chairde'),
#  ('stáisiúin a ndruidim', 'stáisiúin á ndruidim'),
#  ('hachomharc a iarraidh', 'hachomharc á iarraidh'),
#  ('duine a bhíodh', 'duine á bhíodh'),
#  ('leo a chinntiú', 'leo á chinntiú'),
#  ('master’ a deirtear', 'master’ á deirtear'),
#  ('n-éiríonn a leithéid', 'n-éiríonn á leithéid'),
#  ('Nuair a labhair', 'Nuair á labhair'),
#  ('páistí a léann', 'páistí á léann'),
#  ('bhfoghlaim a bhíodh', 'bhfoghlaim á bhíodh'),
#  ('ciníochacha a mhealladh', 'ciníochacha á mhealladh'),
#  ('nua a fhorbairt', 'nua á fhorbairt'),
#  ('Seo a leanas', 'Seo á leanas'),
#  ("sin a d'éirigh", "sin á d'éirigh"),
#  ('duine a bhfuil', 'duine á bhfuil'),
#  ('taraifí a athrú', 'taraifí á athrú'),
#  ('sceimhlitheoir a thug', 'sceimhlitheoir á thug'),
#  ('ar a lán', 'ar á lán'),
#  ('10pm a bheidh', '10pm á bheidh'),
#  ('coinníollach a úsáid', 'coinníollach á úsáid'),
#  ('de a bhíonn', 'de á bhíonn'),
#  ('agus a bhfuil', 'agus á bhfuil'),
#  ('ar a laghad', 'ar á laghad'),
#  ('leanaí a chosaint', 'leanaí á chosaint'),
#  ('áit a mbeidh', 'áit á mbeidh'),
#  ('chisteanach a fhágáil', 'chisteanach á fhágáil'),
#  ('sin a chosaint', 'sin á chosaint'),
#  ('dtaifead a bhíonn', 'dtaifead á bhíonn'),
#  ('Tugadh a raibh', 'Tugadh á raibh'),
#  ('hórdú a chinneadh', 'hórdú á chinneadh'),
#  ('air a pháiste', 'air á pháiste'),
#  ('Cheallaigh a gcluiche', 'Cheallaigh á gcluiche'),
#  ('gá a lán', 'gá á lán'),
#  ('spéis a chuir', 'spéis á chuir'),
#  ('meabhairshláinte a chomhlíonadh', 'meabhairshláinte á chomhlíonadh'),
#  ('(nó a shliocht', '(nó á shliocht'),
#  ('seo a leanas', 'seo á leanas'),
#  ('£7500 a chur', '£7500 á chur'),
#  ('príosúnach a shaoradh', 'príosúnach á shaoradh'),
#  ('chomhluchta a ghreamú', 'chomhluchta á ghreamú'),
#  ('linn a gcruinnithe', 'linn á gcruinnithe'),
#  ('Bheadh a mhacasamhail', 'Bheadh á mhacasamhail'),
#  ('nuair a bhí', 'nuair á bhí'),
#  ('TF a eagrú', 'TF á eagrú'),
#  ('í a cheannach', 'í á cheannach'),
#  ('5Cad a dhéanann', '5Cad á dhéanann'),
#  ("B'in a dúradh", "B'in á dúradh"),
#  ('seo a thugann', 'seo á thugann'),
#  ('é a thógáil', 'é á thógáil'),
#  ('1984 a ghairm', '1984 á ghairm'),
#  ('gearán a chur', 'gearán á chur'),
#  ('Sexton a rugadh', 'Sexton á rugadh'),
#  ('fiosrú a dhéanamh', 'fiosrú á dhéanamh'),
#  ('sonraí a choimeádann', 'sonraí á choimeádann'),
#  ('ar a charachtair', 'ar á charachtair'),
#  ('achtachán a bhaineann', 'achtachán á bhaineann'),
#  ('haiku a bhfuil', 'haiku á bhfuil'),
#  ('ciliméadar a cheannach', 'ciliméadar á cheannach'),
#  ('Nuair a bheidh', 'Nuair á bheidh'),
#  ('Tarrtháladh a comhghleacaithe', 'Tarrtháladh á comhghleacaithe'),
#  ('léitheoirí a n-aigne', 'léitheoirí á n-aigne'),
#  ('gaeilge a bheadh', 'gaeilge á bheadh'),
#  ('uair a bhí', 'uair á bhí'),
#  ('Gaeilge a labhairt', 'Gaeilge á labhairt'),
#  ('éinne a labhair', 'éinne á labhair'),
#  ('agus a bheith', 'agus á bheith'),
#  ('Mise a bheas', 'Mise á bheas'),
#  ('neamhfhoirmiúil a bhunú', 'neamhfhoirmiúil á bhunú'),
#  ('sóisialta) a mholadh', 'sóisialta) á mholadh'),
#  ('Teoiric a bhí', 'Teoiric á bhí'),
#  ('oibre a bhí', 'oibre á bhí'),
#  ('athsholáthair a bheith', 'athsholáthair á bheith'),
#  ('Tacitus a scríobh', 'Tacitus á scríobh'),
#  ('ar a bhfuil', 'ar á bhfuil'),
#  ('léachtaí a bhíonn', 'léachtaí á bhíonn'),
#  ('tAire a mholadh', 'tAire á mholadh'),
#  ('rúnaíocht a sholáthar', 'rúnaíocht á sholáthar'),
#  ('tae a fháil', 'tae á fháil'),
#  ('pleananna a ullmhú', 'pleananna á ullmhú'),
#  ('síos a dhéanamh', 'síos á dhéanamh'),
#  ('Poist a dhiúltú', 'Poist á dhiúltú'),
#  ('eile a bheas', 'eile á bheas'),
#  ('ceadaithe a lamháil', 'ceadaithe á lamháil'),
#  ('Dúnmharú a bhaineann', 'Dúnmharú á bhaineann'),
#  ('greim a choinneáil', 'greim á choinneáil'),
#  ('éis a bheith', 'éis á bheith'),
#  ('(34) a chuirfeadh', '(34) á chuirfeadh'),
#  ('míthreorach a éileamh', 'míthreorach á éileamh'),
#  ('Meánscoileanna a ritheann', 'Meánscoileanna á ritheann'),
#  ('modúil a bhaineann', 'modúil á bhaineann'),
#  ('Gnáth-ghníomhaíochtaí a bhféadfar', 'Gnáth-ghníomhaíochtaí á bhféadfar'),
#  ('faireachán a dhéanamh', 'faireachán á dhéanamh'),
#  ('féin a ghlacadh', 'féin á ghlacadh'),
#  ('nuair a déanadh', 'nuair á déanadh'),
#  ('chomhcheilg a bhí', 'chomhcheilg á bhí'),
#  ('timpeallacht a chruthú', 'timpeallacht á chruthú'),
#  ('cuimsitheach a chur', 'cuimsitheach á chur'),
#  ('réir a chéile', 'réir á chéile'),
#  ('fhírinne a rá', 'fhírinne á rá'),
#  ('bhfiul a fhios', 'bhfiul á fhios'),
#  ('seo a rinneadh', 'seo á rinneadh'),
#  ('Gaillimh a bhí', 'Gaillimh á bhí'),
#  ('121Digital a chríochnú', '121Digital á chríochnú'),
#  ('achmainní a mbaineann', 'achmainní á mbaineann'),
#  ('shuntasacha a rinne', 'shuntasacha á rinne'),
#  ('duine a fháil', 'duine á fháil'),
#  ('eile a tharlaíonn', 'eile á tharlaíonn'),
#  ("ann' a deireadh", "ann' á deireadh"),
#  ("Nuair a d'fhilleamar", "Nuair á d'fhilleamar"),
#  ('í a bheith', 'í á bheith'),
#  ('Mar a deir', 'Mar á deir'),
#  ('fothaoidmheara a mhaireann', 'fothaoidmheara á mhaireann'),
#  ('gcaithfear a bheith', 'gcaithfear á bheith'),
#  ('sin a leagan', 'sin á leagan'),
#  ('machnamh a dhéanamh', 'machnamh á dhéanamh'),
#  ('hiarUachtaráin a bhí', 'hiarUachtaráin á bhí'),
#  ('Rialacháin a bhaineann', 'Rialacháin á bhaineann'),
#  ('nuair a chríochnaigh', 'nuair á chríochnaigh'),
#  ('tubaiste a tharla', 'tubaiste á tharla'),
#  ('dhaonna a mhúnlú', 'dhaonna á mhúnlú'),
#  ('Ceard a mbíonn', 'Ceard á mbíonn'),
#  ('fhéadfá a rá', 'fhéadfá á rá'),
#  ('£4 a bhí', '£4 á bhí'),
#  ('ar a seacht', 'ar á seacht'),
#  ('Laighean a bhíodh', 'Laighean á bhíodh'),
#  ('Alba a bhí', 'Alba á bhí'),
#  ('agus a mhagarlán', 'agus á mhagarlán'),
#  ('í a chuireann', 'í á chuireann'),
#  ('duine a bhí', 'duine á bhí'),
#  ('nuair a tháinig', 'nuair á tháinig'),
#  ('Gníomhaireachta a chomhlíonadh', 'Gníomhaireachta á chomhlíonadh'),
#  ('beartú a dhéanamh', 'beartú á dhéanamh'),
#  ('fostaíochta a fháil', 'fostaíochta á fháil'),
#  ('réasúnta a chuireann', 'réasúnta á chuireann'),
#  ('(foras a bhfuil', '(foras á bhfuil'),
#  ('mé a dhath', 'mé á dhath'),
#  ('dlí a bhaineann', 'dlí á bhaineann'),
#  ('bualadh a thug', 'bualadh á thug'),
#  ('cheist a chur', 'cheist á chur'),
#  ('agus a rá', 'agus á rá'),
#  ('Tíortha a mbíonn', 'Tíortha á mbíonn'),
#  ('smachta a bheith', 'smachta á bheith'),
#  ('is a bpleanáiltear', 'is á bpleanáiltear'),
#  ('feabhas a chur', 'feabhas á chur'),
#  ('fad a rinneadh', 'fad á rinneadh'),
#  ('gealltanais a tugadh', 'gealltanais á tugadh'),
#  ('seo) a fhaibhreoidh', 'seo) á fhaibhreoidh'),
#  ('dearcadh a léiríonn', 'dearcadh á léiríonn'),
#  ("sin a d'fhéadfadh", "sin á d'fhéadfadh"),
#  ('ann a chairde', 'ann á chairde'),
#  ('ceol a scríobh', 'ceol á scríobh'),
#  ('tuiscint a fháil', 'tuiscint á fháil'),
#  ("mhuis' a deir", "mhuis' á deir"),
#  ("torthaí a d'fhéadfadh", "torthaí á d'fhéadfadh"),
#  ('seo a úsáid', 'seo á úsáid'),
#  ('Straitéisí a Thacú', 'Straitéisí á Thacú'),
#  ('rud a dhéanfaidh', 'rud á dhéanfaidh'),
#  ('Rua a réiteach', 'Rua á réiteach'),
#  ('cluichí a imrítear', 'cluichí á imrítear'),
#  ('comhair a dhá', 'comhair á dhá'),
#  ('7 a chlog', '7 á chlog'),
#  ('bhfuil a fhios', 'bhfuil á fhios'),
#  ('Bhí a lámha', 'Bhí á lámha'),
#  ('gach a bhí', 'gach á bhí'),
#  ('cathrach a spreagadh', 'cathrach á spreagadh'),
#  ('imeachtaí a phleanáil', 'imeachtaí á phleanáil'),
#  ('dtáirgí a logánú', 'dtáirgí á logánú'),
#  ('minic a bhaineann', 'minic á bhaineann'),
#  ('cumarsáide a mbeifear', 'cumarsáide á mbeifear'),
#  ('chúrsaí a reáchtáil', 'chúrsaí á reáchtáil'),
#  ('tá a dhóthain', 'tá á dhóthain'),
#  ('ar a 8', 'ar á 8'),
#  ('sin a loghadh', 'sin á loghadh'),
#  ('seo a fheiceáil', 'seo á fheiceáil'),
#  ('mar a mhínítear', 'mar á mhínítear'),
#  ('an-dáiríre a bhíonn', 'an-dáiríre á bhíonn'),
#  ('iontu a bheith', 'iontu á bheith'),
#  ('fhó-ionad a bhunú', 'fhó-ionad á bhunú'),
#  ('daltaí a ullmhú', 'daltaí á ullmhú'),
#  ("agus a réamhstair';", "agus á réamhstair';"),
#  ('aici a theastódh', 'aici á theastódh'),
#  ('ráiteas a bheith', 'ráiteas á bheith'),
#  ('íobartaigh a gceart', 'íobartaigh á gceart'),
#  ('chuige a bhfuil', 'chuige á bhfuil'),
#  ('mar a bhí', 'mar á bhí'),
#  ('as a cuid', 'as á cuid'),
#  ('ar a dtuismitheoirí', 'ar á dtuismitheoirí'),
#  ('thú a chara!', 'thú á chara!'),
#  ('leith a thabhairt', 'leith á thabhairt'),
#  ('Cúl a chur', 'Cúl á chur'),
#  ('Banc a cheadú', 'Banc á cheadú'),
#  ('nuair a bheas', 'nuair á bheas'),
#  ('gcónaí a bheith', 'gcónaí á bheith'),
#  ('stop a chur', 'stop á chur'),
#  ('rang a sé', 'rang á sé'),
#  ('sheirbhís a bainc', 'sheirbhís á bainc'),
#  ('anallód a bhí', 'anallód á bhí'),
#  ('fhuaim a chothromú', 'fhuaim á chothromú'),
#  ('gréasáin a fhorbairt', 'gréasáin á fhorbairt'),
#  ('iomchuí a dhéanamh', 'iomchuí á dhéanamh'),
#  ('mar a thugaim', 'mar á thugaim'),
#  ('eolais a fháil', 'eolais á fháil'),
#  ('ag a mhalartú', 'ag á mhalartú'),
#  ('Athraíodh a bhean', 'Athraíodh á bhean'),
#  ('cad a bhí', 'cad á bhí'),
#  ('2008 a tháinig', '2008 á tháinig'),
#  ('úsáid a bhaint', 'úsáid á bhaint'),
#  ('thionscadail a chur', 'thionscadail á chur'),
#  ('páiste a imríonn', 'páiste á imríonn'),
#  ('é a chuireann', 'é á chuireann'),
#  ('seo a chomhlíonadh', 'seo á chomhlíonadh'),
#  ('coinníollacha a bhaineann', 'coinníollacha á bhaineann'),
#  ('déanaí a eisíodh', 'déanaí á eisíodh'),
#  ('domhanda a chinntiú', 'domhanda á chinntiú'),
#  ('is a rá', 'is á rá'),
#  ('muinín a chur', 'muinín á chur'),
#  ('Cosaintí a bhaineann', 'Cosaintí á bhaineann'),
#  ('spailpín a stór', 'spailpín á stór'),
#  ('spás a fháil', 'spás á fháil'),
#  ('socruithe a dhéanamh', 'socruithe á dhéanamh'),
#  ('acu a hiarraidh', 'acu á hiarraidh'),
#  ('éard a thugtar', 'éard á thugtar'),
#  ('dream a chruthú', 'dream á chruthú'),
#  ('Fáilte a chara', 'Fáilte á chara'),
#  ('meid a bheidh', 'meid á bheidh'),
#  ('Bás a sciobann', 'Bás á sciobann'),
#  ('nua a dhéanamh', 'nua á dhéanamh'),
#  ('ait a dtarraingíonn', 'ait á dtarraingíonn'),
#  ('dearmad a dhéanamh', 'dearmad á dhéanamh'),
#  ('idir a 1-3', 'idir á 1-3'),
#  ('deas a thabhairt', 'deas á thabhairt'),
#  ('seo a chur', 'seo á chur'),
#  ('duine a cheannacht(in', 'duine á cheannacht(in'),
#  ("D'fhéadfá a bheith", "D'fhéadfá á bheith"),
#  ('leithscéal a chairde', 'leithscéal á chairde'),
#  ('uain a bhreith', 'uain á bhreith'),
#  ('bhás a mhná', 'bhás á mhná'),
#  ('Seo a leanas', 'Seo á leanas'),
#  ('deireanach a bhí', 'deireanach á bhí'),
#  ('creidmheasa a lamhálfar', 'creidmheasa á lamhálfar'),
#  ('Bíonn a fhios', 'Bíonn á fhios'),
#  ('áit a Darragh', 'áit á Darragh'),
#  ('é a athair', 'é á athair'),
#  ('bróga a chur', 'bróga á chur'),
#  ('Cathrach a leathnú', 'Cathrach á leathnú'),
#  ('ar a chiontú', 'ar á chiontú'),
#  ('chaoi a ndeachaigh', 'chaoi á ndeachaigh'),
#  ('Nuair a bhíonn', 'Nuair á bhíonn'),
#  ('éiceachórais a fhorfheidhmiú', 'éiceachórais á fhorfheidhmiú'),
#  ('meáchan a chailleadh', 'meáchan á chailleadh'),
#  ('Marley a bhí', 'Marley á bhí'),
#  ('duchasacha a bhfuil', 'duchasacha á bhfuil'),
#  ('[gan a chur', '[gan á chur'),
#  ('Mhacha a bheas', 'Mhacha á bheas'),
#  ('seo a bhaint', 'seo á bhaint'),
#  ('pras a thomhas', 'pras á thomhas'),
#  ('theachtaireacht a Alex', 'theachtaireacht á Alex'),
#  ('sé a bhearna', 'sé á bhearna'),
#  ('oidí a fhostú', 'oidí á fhostú'),
#  ('fáilte a chur', 'fáilte á chur'),
#  ('Tá a gcuid', 'Tá á gcuid'),
#  ('Luimnigh a dhéanann', 'Luimnigh á dhéanann'),
#  ('gearra a insint', 'gearra á insint'),
#  ('cuí a bhainfidh—', 'cuí á bhainfidh—'),
#  ('athrú a chuid', 'athrú á chuid'),
#  ('réaltaí a chur', 'réaltaí á chur'),
#  ('páistí a gcuid', 'páistí á gcuid'),
#  ('heagraíochtaí a bhain', 'heagraíochtaí á bhain'),
#  ("beag a d'inis", "beag á d'inis"),
#  ('é a bhfuil', 'é á bhfuil'),
#  ('Uillinneacha a Thomhas', 'Uillinneacha á Thomhas'),
#  ('gan a bheith', 'gan á bheith'),
#  ('radharc a bhíonn', 'radharc á bhíonn'),
#  ('filí a saothar', 'filí á saothar'),
#  ('gramadaí a éilíonn', 'gramadaí á éilíonn'),
#  ('seo a bheith', 'seo á bheith'),
#  ('spreagadh a léirítear', 'spreagadh á léirítear'),
#  ('Nuair a tháinig', 'Nuair á tháinig'),
#  ('smacht a fháil', 'smacht á fháil'),
#  ('libh a bhuachaillí!', 'libh á bhuachaillí!'),
#  ('ar a laghad', 'ar á laghad'),
#  ('naomhóige a raibh', 'naomhóige á raibh'),
#  ...]

# %%
#expected_runtime = (end-start)*20000
#expected_runtime/60

# %% [markdown]
# ### Try Bigram Model

# %%
def evaluate_model(model, choices):
    results = [['Id','Expected']]
    for index, choice in enumerate(choices):
        c1,c2 = basic_probability(choice[0],choice[1],model)
        results.append([index+1,c1])
    return results

# %%
def evaluate_interp_model(model, choices, weights):
    results = [['Id','Expected']]
    for index, choice in enumerate(choices):
        c1,c2 = interpolate_probability(choice[0],choice[1],model, weights)
        results.append([index+1,c1])
    return results

# %%
results = evaluate_model(model,choices)

# %%
#results

# %%
def write_output(filename,results):
    out_file = open(filename,'w')
    count =0
    for line in results:
        output = str(line[0]) + "," + str(line[1]) + "\n"
        out_file.write(output)
    out_file.close()
    return 1

# %%
def evaluate_results(prediction_file,actual_file):
    with open(prediction_file) as file:
        reader = csv.reader(file)
        predictions = list(reader)
    
    with open(actual_file) as file:
        reader = csv.reader(file)
        actual = list(reader)
    
    if len(actual) != len(predictions):
        print("Error: Files not the same length")
        return
    
    actual = np.array(actual)
    actual = actual[1:,1].astype(np.float64)
    predictions = np.array(predictions)
    predictions = predictions[1:,1].astype(np.float64)
    
    log_loss_score = log_loss(actual, predictions, eps=1e-15)
        
    return log_loss_score

# %%
evaluate_results("First_Dev_Test.csv","dev_answers.csv")
# Out:
# 0.8597526024197777

# %%
def full_pipeline(output_name,train,test,N):
    train_data = prepare_data(train,N)
    model = train_model(train_data,N)
    choices = prepare_test_data(test,N)
    results = evaluate_model(model,choices)
    write_output(output_name,results)

# %%
def full_interp_pipeline(output_name,train,test,N,weights):
    train_data = prepare_data(train,N)
    model = train_model(train_data,N)
    choices = prepare_test_data(test,N)
    results = evaluate_interp_model(model,choices,weights)
    write_output(output_name,results)

# %%
#full_pipeline("trigram_with_bold_reassignment.csv","train.txt","test.txt",3)

# %%
#full_interp_pipeline("interpreted_trigram.csv","train.txt","test.txt",3)

# %%
def full_dev_pipeline(output_name,train,dev_test,dev_answers,N,percent_split,weights):
    train_data = prepare_data(train,N)
    vocab = create_vocab()
    new_train = train_dev_split(train_data, percent_split, vocab, dev_test, dev_answers)
    model = train_model(new_train,N)
    choices = prepare_test_data(dev_test,N)
    results = evaluate_interp_model(model,choices,weights)
    success = write_output(output_name,results)
    score = evaluate_results(output_name,dev_answers)
    return score

# %%
score = full_dev_pipeline("First_Dev_Test.csv","train.txt","dev_test.txt","dev_answers.csv",3,10,[0.2,0.7,0.1])
score
# Out:
# 0.29523988463921635

# %%
for x in np.arange(0,1.1,0.1):
    if x == 1:
        weights = [x,0,0]
        print(weights,full_dev_pipeline("a.csv","train.txt","dev_test.txt","dev_answers.csv",3,10,weights))
    for y in np.arange (0,1.05-x,0.1):
        z = 1-y-x
        weights = [x,y,z]
        print(weights,full_dev_pipeline("a.csv","train.txt","dev_test.txt","dev_answers.csv",3,10,weights))
# Out:
# [0.0, 0.0, 1.0] 0.37767889720689996
# [0.0, 0.1, 0.9] 0.3377886110497794
# [0.0, 0.2, 0.8] 0.313699857891837
# [0.0, 0.30000000000000004, 0.7] 0.29397317650376176
# [0.0, 0.4, 0.6] 0.2744637773889263
# [0.0, 0.5, 0.5] 0.2597998781991521
# [0.0, 0.6000000000000001, 0.3999999999999999] 0.2471187742141428
# [0.0, 0.7000000000000001, 0.29999999999999993] 0.23843004811530533
# [0.0, 0.8, 0.19999999999999996] 0.22937582651983793
# [0.0, 0.9, 0.09999999999999998] 0.22059384338933827
# [0.0, 1.0, 0.0] 0.22163925290300135
# [0.1, 0.0, 0.9] 0.3461718933359337
# [0.1, 0.1, 0.8] 0.3219281964716464
# [0.1, 0.2, 0.7000000000000001] 0.297256270254709
# [0.1, 0.30000000000000004, 0.6] 0.2755222487922954
# [0.1, 0.4, 0.5] 0.26069576110614917
# [0.1, 0.5, 0.4] 0.24583992664291304
# [0.1, 0.6000000000000001, 0.29999999999999993] 0.2334108156847355
# [0.1, 0.7000000000000001, 0.19999999999999993] 0.22618134328552997
# [0.1, 0.8, 0.09999999999999995] 0.2174597713244505
# [0.1, 0.9, -2.7755575615628914e-17] 0.21202272670899094
# [0.2, 0.0, 0.8] 0.32469242216414584
# [0.2, 0.1, 0.7] 0.30415864443851126
# [0.2, 0.2, 0.6000000000000001] 0.28313167467565353
# [0.2, 0.30000000000000004, 0.49999999999999994] 0.26536477505982736
# [0.2, 0.4, 0.39999999999999997] 0.251994483563706
